# %% [markdown]
# <a href="https://colab.research.google.com/github/kazuki0505/zaico-fixcan_heroku/blob/master/mBall_yahoo5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # mBall_yahoo6 を作らず、5をコミットしてみ

# %%
# 4 は、SQL バージョン
##

# While i <151: つまり商品数１５１まで＝５０件/ページの３ページまでスクレイプする　
# mongoDB 無視
# これは、mBallの機能を担うコード。mBall_atk.pyも吸収してみた
# 　# mBall_yahooもmBall_atkも、画像１枚目を取得するかしないかの違いで、ほかは全く同じだから


import pandas as pd
import numpy as np
# from openpyxl import load_workbook
import time
import re

import requests, bs4
# import lxml.html
# from pymongo import MongoClient
# import xlwings as xw
# import math
# from selenium import webdriver
# from selenium.common.exceptions import NoSuchElementException
# from xlwings.constants import AutoFillType
# import shutil
from datetime import datetime
from uuid import uuid4
from googletrans import Translator
import json
# import pandas as pd
# import pythoncom
# from pythoncom import com_error
# import win32com.client
# import win32com
# import sys
import psycopg2
from sqlalchemy import create_engine

# %%
# def main():
    # check_if_Excel_runs()
    # wb = r'C:\Users\Kazuki Yuno\Desktop\00.myself\04.Buyer\0.リサーチ\keyword\key_generator.xlsx'

# データベースの接続情報
connection_config = {
    'user': 'postgres',
    'password': 'larc1225',
    'host': 'localhost',
    'port': '5432',  # なくてもOK
    'database': 'scraping'
}
global engine
engine = create_engine(
    'postgresql://postgres:larc1225@localhost:5432/scraping'.format(**connection_config))

    # 検索キーは、後の間を＋にする必要があるが、これエクセルの時点でやるか、ここでやるか> planner では空白で複合キーを生成するので、変更はここで

# %%
market_df = pd.read_sql('market', con=engine, # SELECT文ではなく、テーブル名のみ
    columns=['categ num', 'main key', 'キーフレーズ'])\
    .dropna(subset=['キーフレーズ']) # キーフレーズ列のNan を消して表示

categ_num_list = market_df.iloc[:, 0]#'categ num']
mainKey_list = market_df.iloc[:, 1]#'main key'
keyPhrase_list = market_df.iloc[:, 2] #['X-MEN 同人誌', 'batman 同人誌'] #.get_group('X-MEN 同人誌', 'batman 同人誌') # 検索キーを減らしたいなら、ここで
                                # iloc、第一引数が行
# app = xw.App(visible=True)  # False)
# wb2 = app.books.open(atk)
# sht2 = wb2.sheets[0]

market_df
# Out:
#      categ num            main key            キーフレーズ
# 1      73466.0      incense burner                香炉
# 2      73466.0        tea ceremony                茶道
# 4      73466.0     buddhist copper               仏 銅
# 5      73466.0      buddhist altar              仏 飾台
# 6      73466.0        buddhist art            仏像 アート
# 8      73466.0    kanzashi hairpin             かんざし
# 11     73466.0        lacquer ware            漆塗り 骨董
# 20     73466.0                bell           鐘 鈴 骨董品
# 22     73466.0           sculpture             彫刻 香炉
# 23     73466.0           sculpture              彫刻 銅
# 24     73466.0           sculpture              彫刻 木
# 25     73466.0           sculpture              彫刻 龍
# 26     73466.0           sculpture             彫刻 獅子
# 28     38125.0     painting scroll            掛け軸 風景
# 29     38125.0     painting scroll             掛け軸 絹
# 30     38125.0     painting scroll             掛け軸 石
# 31     38125.0     painting scroll            掛け軸 山水
# 34     38126.0              prints             絵 浮世絵
# 35     38126.0              prints             絵 木版画
# 37     38126.0              prints             絵 歌舞伎
# 38     38126.0              prints           絵 喜多川歌麿
# 39     38126.0              prints            絵 葛飾北斎
# 40     38126.0              prints            絵 歌川広重
# 42     38126.0              prints              絵 春画
# 43     37935.0               bowls            茶碗 ガラス
# 44     37935.0               bowls             茶碗 緑茶
# 45     37935.0               bowls           茶碗 パターン
# 46     37935.0               bowls        茶碗 サイン入り 箱
# 47     37935.0               bowls            茶碗 瀬戸焼
# 48     37935.0               bowls            茶碗 清水焼
# 52     37935.0               bowls           茶碗 伊万里焼
# 53     37935.0               bowls            茶碗 九谷焼
# 54     37935.0               bowls           茶碗 伊万里焼
# 69     66841.0              katana                 鞘
# 70     66841.0              katana                 鍔
# 71     66841.0              katana                目貫
# 112     1345.0  shingeki no kyojin    進撃の巨人 フィギュア 限定
# 119    13666.0         dragon ball  ドラゴンボール フィギュア 限定
# 122   158671.0              batman        batman 同人誌
# 123   158671.0              batman       コトブキヤ バットマン
# 125   158671.0           spiderman     コトブキヤ スパイダーマン
# 127    17085.0               x-men         X-MEN 同人誌
# 128   158671.0               x-men       コトブキヤ x-men
# 130   158671.0            avengers     コトブキヤ アベンジャーズ
# 131    75708.0           star wars     コトブキヤ スターウォーズ

# %%
def remove_space_htmlTag(s):
    p = re.compile(r"<[^>]*?>") # htmlTagを削除
    remove = p.sub("", s)
    space = re.sub(r'\s+', ' ', remove).strip()  # 連続する空白を1つのスペースに置き換え、前後の空白を削除した新しい文字列を取得する。
    return space.replace('[', '').replace(']', '') # [] を置換

def remove_space_htmlTag_pr(s):
    p = re.compile(r"<[^>]*?>") # htmlTagを削除
    remove = p.sub("", s)
    space = re.sub(r'\s+', ' ', remove).strip()  # 連続する空白を1つのスペースに置き換え、前後の空白を削除した新しい文字列を取得する。
    return space.replace('[', '').replace(']', '').replace('円（税 0 円） ', '')


 # mergeのURL列から、新たにitemID 列を導き出す
def extract_key(url): # URLからキー（URLの末尾のISBN）を抜き出す。
    m = re.search(r'/([^/]+)$', url) # /([^/]+)$
    return m.group(1)

# %%
list_df = pd.DataFrame(columns=['タイトル', 'url', 'ID', 'Title', 'main key', 'Category'])
list_df
# Out:
# Empty DataFrame
# Columns: [タイトル, url, ID, Title, main key, Category]
# Index: []

# %%
# arr_title_url_id_ = np.empty([0, 3])

  #                                        0~ other japanese antique  14~ painting  18= prints
#                                             ドラゴンボール 37  ラストは４５
        # これは不便、カテゴリ指定で検索ワードをグループ化しながら、毎日自動リサしてほしい
# keyPhraase 番号振っても、途中からのリサにならない
# ここ、keyPhraseだけ番号振ったらだめ、mainKryやcategは最初から記録してしまう>> 一括で番を振る
# list(zip()) とすることで、一括して順番を指定できる　https://stackoverrun.com/ja/q/7531087
for mainKey, categ_num, keyPhrase in list(zip(mainKey_list, categ_num_list, keyPhrase_list))[44:]: #[36:]: # [:2]
    print(mainKey, categ_num, keyPhrase)
    # url = 'https://auctions.yahoo.co.jp/search/search' # while 内に入れることで解決。ここだと、2ページ目の頭の品のページに行ってしまう
    url_list = []
    title_list = [] # 空のDFを2列分用意し、append する方法もあるはずだが、次回
    itemid_list = []
    # price_list = []
    i = 1
    while i < 61: # 151 20ずつ or 50ずつ繰り上がる
        url = 'https://auctions.yahoo.co.jp/search/search' # 正規表現による置換はやめた
        # カテゴリ別に、Param設定を買えられる。If "ドラゴンボール フィギュア" : 即決品のみ
        params = {'q': keyPhrase, 'va': keyPhrase, 'exflg': '1', 'b': i, 'n': '20', # 50, 100
                  'min': '4000', 'max': '51999', 'price_type': 'bidorbuyprice'}
        # 注意: 即決のみにするには、min かmaxを指定する必要がある
        # # 'istatus': '',
        res = requests.get(url, params=params)
        print(res.url)
        
        res.raise_for_status()
        soup = bs4.BeautifulSoup(res.text, "html.parser")
        #   url_list = []
        # scrape_list_page(soup, url_list, title_list)
        elems = soup.select("a[class='Product__titleLink']")
        for a in elems:  # '#listBook a[itemprop="url"]'):
        # print(a)
            elem_url = a.get('href')
            print(elem_url)
            
            url_list.append(elem_url)
            # time.sleep(1)
            # yield url
            # title
            itemid = extract_key(elem_url)
            itemid_list.append(itemid)
        # title_list = []
        elems = soup.select("a[class='Product__titleLink']")
        # elems = soup.select("#allContents > div.l-wrapper.cf > div.l-contents > div.l-contentsBody > div > div.Result__body > div.Products.Products--grid > div > ul > li:nth-child(1) > div.Product__detail > h3 > a")
        for elem in elems:
        # print(elem)
            title = elem.get('title')
            # print(elem)
            title_list.append(title)
            print(title)
            
        # 価格
        # elems = soup.select("span[class='Product__priceValue.u-textRed']")

        # print('OK')
        i += 20
        time.sleep(3)
        break
    # 重複分はATKに追加しないようにする
# Out:
# star wars 75708.0 コトブキヤ スターウォーズ
# https://auctions.yahoo.co.jp/search/search?q=%E3%82%B3%E3%83%88%E3%83%96%E3%82%AD%E3%83%A4+%E3%82%B9%E3%82%BF%E3%83%BC%E3%82%A6%E3%82%A9%E3%83%BC%E3%82%BA&va=%E3%82%B3%E3%83%88%E3%83%96%E3%82%AD%E3%83%A4+%E3%82%B9%E3%82%BF%E3%83%BC%E3%82%A6%E3%82%A9%E3%83%BC%E3%82%BA&exflg=1&b=1&n=20&min=4000&max=51999&price_type=bidorbuyprice
# https://page.auctions.yahoo.co.jp/jp/auction/r403051715
# https://page.auctions.yahoo.co.jp/jp/auction/494400497
# https://page.auctions.yahoo.co.jp/jp/auction/p776025227
# https://page.auctions.yahoo.co.jp/jp/auction/w409986028
# https://page.auctions.yahoo.co.jp/jp/auction/v737950789
# https://page.auctions.yahoo.co.jp/jp/auction/l582401971
# https://page.auctions.yahoo.co.jp/jp/auction/v722095628
# https://page.auctions.yahoo.co.jp/jp/auction/o398652405
# https://page.auctions.yahoo.co.jp/jp/auction/b492567732
# https://page.auctions.yahoo.co.jp/jp/auction/w408157122
# https://page.auctions.yahoo.co.jp/jp/auction/k483497145
# https://page.auctions.yahoo.co.jp/jp/auction/f446222729
# https://page.auctions.yahoo.co.jp/jp/auction/d408120162
# https://page.auctions.yahoo.co.jp/jp/auction/o396314149
# https://page.auctions.yahoo.co.jp/jp/auction/u375426818
# https://page.auctions.yahoo.co.jp/jp/auction/p763925243
# https://page.auctions.yahoo.co.jp/jp/auction/b468858355
# https://page.auctions.yahoo.co.jp/jp/auction/o395835275
# https://page.auctions.yahoo.co.jp/jp/auction/q384628921
# https://page.auctions.yahoo.co.jp/jp/auction/u366330133
# コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・フェット、ダースベイダー、C-3PO & R2-D2)
# ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# レア☆精巧☆コトブキヤ　ダースモール スターウォーズ SW 美品　寿屋壽屋
# 訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア コトブキヤ
# IG-2 スターウォーズ フィギュア 1/10 ARTFX+ コトブキヤ
# 未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス フィギュア kotobukiya ②
# スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ KOTOBUKIYA
# コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive Edition / B00JA919Z2-48
# 内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア kotobukiya
# 未開封 ダース・ベイダー 1/7 ARTFX STAR WARS スター・ウォーズ コトブキヤ
# コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール　未開封
# ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッドプレミアムフィギュア」スター・ウォーズ
# 即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ フィギュア 壽屋 SW ホットトイズ
# 【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7スケールフィギュア / B003XTKMBC-110
# スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PVC製 塗装済(中古品)

# %%
    # title_list をATｋのタイトル列と比べ、もし重複していれば, title_listから重複分を削除. # ２つの円のベン図の半月 = df - merge(inner)
    # title_listとurl_list を接合 （titleだけ重複分を消しても、urlが残っているんじゃズレが生じるから
    df1 = pd.DataFrame({'タイトル': title_list, 'url': url_list, 'ID': itemid_list}) #, columns=['SKU']) # 2つのリストを一つのDFに
    # pd.DataFrame({'Mean': mean, 'Median': med, 'SD': sd})
    # ここにsql_df 入れなくて良い？？ >> ループごとに、追加したてのタイトルも比較対象にしたいから、ここに入れて。違うキーで調べても、同じ品を取るケースに備えて
    df1
# Out:
#                                                  タイトル  \
# 0          コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1   コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4             コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 5               レア☆精巧☆コトブキヤ　ダースモール スターウォーズ SW 美品　寿屋壽屋
# 6   訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 7                IG-2 スターウォーズ フィギュア 1/10 ARTFX+ コトブキヤ
# 8   未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 9   スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 10  コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 11  内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 12    未開封 ダース・ベイダー 1/7 ARTFX STAR WARS スター・ウォーズ コトブキヤ
# 13  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 14  ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 15  即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 16  【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 17        スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 18    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 19  コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#
#                                                   url          ID
# 0   https://page.auctions.yahoo.co.jp/jp/auction/r...  r403051715
# 1   https://page.auctions.yahoo.co.jp/jp/auction/4...   494400497
# 2   https://page.auctions.yahoo.co.jp/jp/auction/p...  p776025227
# 3   https://page.auctions.yahoo.co.jp/jp/auction/w...  w409986028
# 4   https://page.auctions.yahoo.co.jp/jp/auction/v...  v737950789
# 5   https://page.auctions.yahoo.co.jp/jp/auction/l...  l582401971
# 6   https://page.auctions.yahoo.co.jp/jp/auction/v...  v722095628
# 7   https://page.auctions.yahoo.co.jp/jp/auction/o...  o398652405
# 8   https://page.auctions.yahoo.co.jp/jp/auction/b...  b492567732
# 9   https://page.auctions.yahoo.co.jp/jp/auction/w...  w408157122
# 10  https://page.auctions.yahoo.co.jp/jp/auction/k...  k483497145
# 11  https://page.auctions.yahoo.co.jp/jp/auction/f...  f446222729
# 12  https://page.auctions.yahoo.co.jp/jp/auction/d...  d408120162
# 13  https://page.auctions.yahoo.co.jp/jp/auction/o...  o396314149
# 14  https://page.auctions.yahoo.co.jp/jp/auction/u...  u375426818
# 15  https://page.auctions.yahoo.co.jp/jp/auction/p...  p763925243
# 16  https://page.auctions.yahoo.co.jp/jp/auction/b...  b468858355
# 17  https://page.auctions.yahoo.co.jp/jp/auction/o...  o395835275
# 18  https://page.auctions.yahoo.co.jp/jp/auction/q...  q384628921
# 19  https://page.auctions.yahoo.co.jp/jp/auction/u...  u366330133

# %%
    sql_df = pd.read_sql('atklist2', con=engine,
                         columns=['タイトル'])  # skiprows=2, encoding='cp932') #.columns = ['title']
    # for index, row in df.iterrows():
    #     if row # row['開始価格'] == row['開始価格2']
    #         df.drop(index, inplace=True)
    sql_df
# Out:
#                                                    タイトル
# 0                                 ドラゴンボール　一番くじ　J賞　墨式タオル
# 1     【内袋未開封】ドラゴンボールＺ Grandista Resolution of Soldie...
# 2           ☆一番くじ ドラゴンボール サイヤ人超決戦 E賞 超サイヤ人ブロリー ’93 未開封♪
# 3     ☆新品 ドラゴンボール超 一番くじ VS EXISTENCE/ラストワン賞 孫悟空＆孫悟飯フ...
# 4     ドラゴンボール SMSP SUPER MASTER STARS PIECE スーパーサイヤ人...
# ...                                                 ...
# 3003           香木　銘「春雨」約0.46g 伽羅　羅国　真那賀　真南蛮　佐曽羅　寸聞多羅　聞香
# 3004         香木　銘「うぐひす」約0.60g 伽羅　羅国　真那賀　真南蛮　佐曽羅　寸聞多羅　聞香
# 3005                                            古銅　豆香炉
# 3006                              ベトナム産 本物 香木 沈香　天然 ２９G
# 3007  新品 1/10 ARTFX+ STAR WARS ファースト・オーダー・ストームトルーパー・...
#
# [3008 rows x 1 columns]

# %%
    on = ['タイトル']  # , 'url'] # https://stackoverflow.com/questions/48912242/how-to-drop-duplicates-from-one-data-frame-if-found-in-another-dataframe
    merge = df1.merge(sql_df[on], on=on, how='left', indicator=True)\
        .query('_merge == "left_only"').drop('_merge', 1) # 左＝df1にのみ存在する（(df2との重複を除く）タイトルにQueryしたあと、merge列を削除
#     print(
    merge # タイトルと url
    
    # 既存のATKタイトルと、リサ結果のタイトルの重複は消えるが、結果タイトル(df1)内での重複は消えない
    # ループごとにatk を保存し、df2読み込む毎に各ループ更新直後のリストを読み込めばいい
# Out:
#                                                  タイトル  \
# 0          コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1   コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4             コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 6   訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 8   未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 9   スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 10  コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 11  内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 13  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 14  ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 15  即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 16  【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 17        スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 18    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 19  コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#
#                                                   url          ID
# 0   https://page.auctions.yahoo.co.jp/jp/auction/r...  r403051715
# 1   https://page.auctions.yahoo.co.jp/jp/auction/4...   494400497
# 2   https://page.auctions.yahoo.co.jp/jp/auction/p...  p776025227
# 3   https://page.auctions.yahoo.co.jp/jp/auction/w...  w409986028
# 4   https://page.auctions.yahoo.co.jp/jp/auction/v...  v737950789
# 6   https://page.auctions.yahoo.co.jp/jp/auction/v...  v722095628
# 8   https://page.auctions.yahoo.co.jp/jp/auction/b...  b492567732
# 9   https://page.auctions.yahoo.co.jp/jp/auction/w...  w408157122
# 10  https://page.auctions.yahoo.co.jp/jp/auction/k...  k483497145
# 11  https://page.auctions.yahoo.co.jp/jp/auction/f...  f446222729
# 13  https://page.auctions.yahoo.co.jp/jp/auction/o...  o396314149
# 14  https://page.auctions.yahoo.co.jp/jp/auction/u...  u375426818
# 15  https://page.auctions.yahoo.co.jp/jp/auction/p...  p763925243
# 16  https://page.auctions.yahoo.co.jp/jp/auction/b...  b468858355
# 17  https://page.auctions.yahoo.co.jp/jp/auction/o...  o395835275
# 18  https://page.auctions.yahoo.co.jp/jp/auction/q...  q384628921
# 19  https://page.auctions.yahoo.co.jp/jp/auction/u...  u366330133

# %%
merge=merge.reset_index(drop=True)
merge
# Out:
#                                                  タイトル  \
# 0          コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1   コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4             コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 5   訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 6   未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 7   スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 8   コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 9   内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 10  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 11  ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 12  即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 13  【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 14        スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 16  コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#
#                                                   url          ID
# 0   https://page.auctions.yahoo.co.jp/jp/auction/r...  r403051715
# 1   https://page.auctions.yahoo.co.jp/jp/auction/4...   494400497
# 2   https://page.auctions.yahoo.co.jp/jp/auction/p...  p776025227
# 3   https://page.auctions.yahoo.co.jp/jp/auction/w...  w409986028
# 4   https://page.auctions.yahoo.co.jp/jp/auction/v...  v737950789
# 5   https://page.auctions.yahoo.co.jp/jp/auction/v...  v722095628
# 6   https://page.auctions.yahoo.co.jp/jp/auction/b...  b492567732
# 7   https://page.auctions.yahoo.co.jp/jp/auction/w...  w408157122
# 8   https://page.auctions.yahoo.co.jp/jp/auction/k...  k483497145
# 9   https://page.auctions.yahoo.co.jp/jp/auction/f...  f446222729
# 10  https://page.auctions.yahoo.co.jp/jp/auction/o...  o396314149
# 11  https://page.auctions.yahoo.co.jp/jp/auction/u...  u375426818
# 12  https://page.auctions.yahoo.co.jp/jp/auction/p...  p763925243
# 13  https://page.auctions.yahoo.co.jp/jp/auction/b...  b468858355
# 14  https://page.auctions.yahoo.co.jp/jp/auction/o...  o395835275
# 15  https://page.auctions.yahoo.co.jp/jp/auction/q...  q384628921
# 16  https://page.auctions.yahoo.co.jp/jp/auction/u...  u366330133

# %% [markdown]
# #### While try をコメントアウトしてるから後で戻して
# #### リスト作成時、名前に連番が入ってしまうのを解決して
# #### 18行にタイトルではない値が追加されてしまう＞iloc[i: i+1] の部分で、例えば17行まで来ると... ilocでインデックス17 =18行目（＝値なし）まで翻訳してリストにappendすることになる。 ＞＞ while len(merge) >= i: の = を外すことで解決。

# %%
    # タイトル整形、英訳前に>> HTML削除、不要文字置換
    # merge2 = remove_space_htmlTag(merge.iloc[:, 1])

    # タイトル翻訳
     # タイトル列に絞り、字数制限、余分の絵文字などを排除
    def left(text, n):
        return text[:n]
    merge_title = left(merge['タイトル'], 75).replace("e.g.", "").replace("™", "").replace("♥", "").replace("½", "").replace("★", "").replace("&", "").replace("◆", "").replace("■", "")
#     merge_title = merge_title.reset_index()
    print(merge_title)
    
    # ループで一行ずつ翻訳、Excelに入力＞ 一行ずつ翻訳、リストにしてSeries化
    translator = Translator()
    i = 0
    title_en_list = []
#     print(len(merge))
#     print(len(merge_title))
    while len(merge) > i: # 制限達したら、これパスしてXW転記もしないことにする。　一度エラー起きれば、リトライしてもずっとエラーだから、While要らない
        try:
#         print('a')
        # lastRow_title2 = sht2.range('F4').end(-4121).row  # ATK H=タイトル列
        # # lastRow_title2 = df2.iloc[:, 5].tail(n) # F= ５番目= 英訳の列  # tail(n)で、最下行を求める
        # nextRow2 = lastRow_title2 + 1

        # 文字列制限＋記号の置換をしてから、翻訳。
#             def left(text, n):
#                 return text[:n]
#             merge
#             merge_title = left(merge['タイトル'], 75).replace("e.g.", "").replace("™", "").replace("♥", "").replace("½", "").replace("★", "").replace("&", "").replace("◆", "").replace("■", "")
#             print(merge_title)
            # 英訳
            merge_en = merge_title.iloc[i: i+1]#.apply( #一行ずつ翻訳
#                 translator.translate, src='ja', dest='en').apply(getattr, args=('text',))
#
#             上記の２行で、17行目の余分な値が発生している。Series[]

            print(merge_en)  # 1つのSeries　になる
            title_en_list.append(merge_en)

            # df2.iloc[nextRow2, 5] = merge_en # 5列目, nextrowの行から
            # sht2.range('F{}'.format(nextRow2)).options(
            #     pd.Series, expand='table', index=False, header=None).value = merge_en

            i += 1

        except json.decoder.JSONDecodeError as e:
            print(str(e) + ' json Decoder Error 発生。本日の上限を達した模様。次へ') #リトライ...')
            break
            # time.sleep(1)
            # continue ここContinueのせいで、以降の作動にはいかず、次の検索フレーズループへ進む
            
#         break
#     print(len(title_en_list)) #やはり１８行カウントされるから黒
#     merge_en
    title_en_list
# Out:
# 0            コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1     コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                  ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                  【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4               コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 5     訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 6     未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 7     スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 8     コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 9     内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 14          スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 15      コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
# Name: タイトル, dtype: object
# 0    コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# Name: タイトル, dtype: object
# 1    コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# Name: タイトル, dtype: object
# 2    ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# Name: タイトル, dtype: object
# 3    【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# Name: タイトル, dtype: object
# 4    コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# Name: タイトル, dtype: object
# 5    訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# Name: タイトル, dtype: object
# 6    未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# Name: タイトル, dtype: object
# 7    スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# Name: タイトル, dtype: object
# 8    コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# Name: タイトル, dtype: object
# 9    内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# Name: タイトル, dtype: object
# 10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# Name: タイトル, dtype: object
# 11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# Name: タイトル, dtype: object
# 12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# Name: タイトル, dtype: object
# 13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# Name: タイトル, dtype: object
# 14    スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# Name: タイトル, dtype: object
# 15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# Name: タイトル, dtype: object
# 16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
# Name: タイトル, dtype: object
# [0    コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
#  Name: タイトル, dtype: object,
#  1    コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
#  Name: タイトル, dtype: object,
#  2    ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
#  Name: タイトル, dtype: object,
#  3    【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
#  Name: タイトル, dtype: object,
#  4    コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
#  Name: タイトル, dtype: object,
#  5    訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
#  Name: タイトル, dtype: object,
#  6    未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
#  Name: タイトル, dtype: object,
#  7    スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
#  Name: タイトル, dtype: object,
#  8    コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
#  Name: タイトル, dtype: object,
#  9    内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
#  Name: タイトル, dtype: object,
#  10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
#  Name: タイトル, dtype: object,
#  11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
#  Name: タイトル, dtype: object,
#  12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
#  Name: タイトル, dtype: object,
#  13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
#  Name: タイトル, dtype: object,
#  14    スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
#  Name: タイトル, dtype: object,
#  15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
#  Name: タイトル, dtype: object,
#  16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#  Name: タイトル, dtype: object]

# %%
    
    # ここでSQLテーブルのタイトル列へ自動で移動する
    title_en_list_sr = pd.Series(title_en_list, name='Title', index=None).reset_index(drop=True)#, inplace=True)#, index=None)#, name=None)
    # merge_en.columns = 'Title'  # 列名をTitleにすることで、SQLのTitle列に追加される
    title_en_list_sr
# Out:
# 0     0    コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品...
# 1     1    コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリア...
# 2     2    ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# Name...
# 3     3    【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# Name...
# 4     4    コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# N...
# 5     5    訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フ...
# 6     6    未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシ...
# 7     7    スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コ...
# 8     8    コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Excl...
# 9     9    内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギ...
# 10    10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1...
# 11    11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ...
# 12    12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & ...
# 13    13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ...
# 14    14    スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 ...
# 15    15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1...
# 16    16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10ス...
# Name: Title, dtype: object

# %%
    # break
    # lastRow_title1 = sht2.range('H4').end(-4121).row  # ATK H=タイトル列
    # lastRow_title1 = df2.iloc[:, 7].tail(n) # H= 7
    # nextRow = lastRow_title1 + 1

    # URLとタイトルのDF=mergeを、to_sql
    # merge（URLとタイトルのdf） にmainkey, categ_numのdfを加え、SQL。
    main_categ_df = pd.DataFrame({'main key': mainKey, 'Category': categ_num},
                                 index=[0, 1]) # index入れないとエラーになる　http://nishidy.hatenablog.com/entry/2016/03/10/015337
    main_categ_df
# Out:
#     main key  Category
# 0  star wars   75708.0
# 1  star wars   75708.0

# %% [markdown]
# ### main_categのインデックスを空白から数字にすると、横連結すると起きた ValueError: Shape of passed values is... というのが解決した

# %%
concat = pd.concat([merge, title_en_list_sr, main_categ_df], axis=1)
# concat = pd.concat([merge, main_categ_df], axis=1)
concat
# Out:
#                                                  タイトル  \
# 0          コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1   コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4             コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 5   訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 6   未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 7   スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 8   コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 9   内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 10  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 11  ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 12  即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 13  【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 14        スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 16  コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#
#                                                   url          ID  \
# 0   https://page.auctions.yahoo.co.jp/jp/auction/r...  r403051715
# 1   https://page.auctions.yahoo.co.jp/jp/auction/4...   494400497
# 2   https://page.auctions.yahoo.co.jp/jp/auction/p...  p776025227
# 3   https://page.auctions.yahoo.co.jp/jp/auction/w...  w409986028
# 4   https://page.auctions.yahoo.co.jp/jp/auction/v...  v737950789
# 5   https://page.auctions.yahoo.co.jp/jp/auction/v...  v722095628
# 6   https://page.auctions.yahoo.co.jp/jp/auction/b...  b492567732
# 7   https://page.auctions.yahoo.co.jp/jp/auction/w...  w408157122
# 8   https://page.auctions.yahoo.co.jp/jp/auction/k...  k483497145
# 9   https://page.auctions.yahoo.co.jp/jp/auction/f...  f446222729
# 10  https://page.auctions.yahoo.co.jp/jp/auction/o...  o396314149
# 11  https://page.auctions.yahoo.co.jp/jp/auction/u...  u375426818
# 12  https://page.auctions.yahoo.co.jp/jp/auction/p...  p763925243
# 13  https://page.auctions.yahoo.co.jp/jp/auction/b...  b468858355
# 14  https://page.auctions.yahoo.co.jp/jp/auction/o...  o395835275
# 15  https://page.auctions.yahoo.co.jp/jp/auction/q...  q384628921
# 16  https://page.auctions.yahoo.co.jp/jp/auction/u...  u366330133
#
#                                                 Title   main key  Category
# 0   0    コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品...  star wars   75708.0
# 1   1    コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリア...  star wars   75708.0
# 2   2    ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# Name...        NaN       NaN
# 3   3    【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# Name...        NaN       NaN
# 4   4    コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# N...        NaN       NaN
# 5   5    訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フ...        NaN       NaN
# 6   6    未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシ...        NaN       NaN
# 7   7    スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コ...        NaN       NaN
# 8   8    コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Excl...        NaN       NaN
# 9   9    内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギ...        NaN       NaN
# 10  10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1...        NaN       NaN
# 11  11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ...        NaN       NaN
# 12  12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & ...        NaN       NaN
# 13  13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ...        NaN       NaN
# 14  14    スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 ...        NaN       NaN
# 15  15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1...        NaN       NaN
# 16  16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10ス...        NaN       NaN

# %%
concat = concat.fillna(method='pad')
concat
# Out:
#                                                  タイトル  \
# 0          コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1   コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4             コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 5   訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 6   未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 7   スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 8   コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 9   内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 10  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 11  ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 12  即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 13  【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 14        スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 16  コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#
#                                                   url          ID  \
# 0   https://page.auctions.yahoo.co.jp/jp/auction/r...  r403051715
# 1   https://page.auctions.yahoo.co.jp/jp/auction/4...   494400497
# 2   https://page.auctions.yahoo.co.jp/jp/auction/p...  p776025227
# 3   https://page.auctions.yahoo.co.jp/jp/auction/w...  w409986028
# 4   https://page.auctions.yahoo.co.jp/jp/auction/v...  v737950789
# 5   https://page.auctions.yahoo.co.jp/jp/auction/v...  v722095628
# 6   https://page.auctions.yahoo.co.jp/jp/auction/b...  b492567732
# 7   https://page.auctions.yahoo.co.jp/jp/auction/w...  w408157122
# 8   https://page.auctions.yahoo.co.jp/jp/auction/k...  k483497145
# 9   https://page.auctions.yahoo.co.jp/jp/auction/f...  f446222729
# 10  https://page.auctions.yahoo.co.jp/jp/auction/o...  o396314149
# 11  https://page.auctions.yahoo.co.jp/jp/auction/u...  u375426818
# 12  https://page.auctions.yahoo.co.jp/jp/auction/p...  p763925243
# 13  https://page.auctions.yahoo.co.jp/jp/auction/b...  b468858355
# 14  https://page.auctions.yahoo.co.jp/jp/auction/o...  o395835275
# 15  https://page.auctions.yahoo.co.jp/jp/auction/q...  q384628921
# 16  https://page.auctions.yahoo.co.jp/jp/auction/u...  u366330133
#
#                                                 Title   main key  Category
# 0   0    コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品...  star wars   75708.0
# 1   1    コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリア...  star wars   75708.0
# 2   2    ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# Name...  star wars   75708.0
# 3   3    【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# Name...  star wars   75708.0
# 4   4    コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# N...  star wars   75708.0
# 5   5    訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フ...  star wars   75708.0
# 6   6    未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシ...  star wars   75708.0
# 7   7    スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コ...  star wars   75708.0
# 8   8    コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Excl...  star wars   75708.0
# 9   9    内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギ...  star wars   75708.0
# 10  10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1...  star wars   75708.0
# 11  11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ...  star wars   75708.0
# 12  12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & ...  star wars   75708.0
# 13  13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ...  star wars   75708.0
# 14  14    スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 ...  star wars   75708.0
# 15  15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1...  star wars   75708.0
# 16  16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10ス...  star wars   75708.0

# %% [markdown]
# ### DF空箱にループ追加

# %%
list_df = list_df.append(concat, ignore_index=True)
list_df
# Out:
#                                                  タイトル  \
# 0          コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1   コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4             コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 5   訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 6   未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 7   スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 8   コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 9   内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 10  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 11  ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 12  即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 13  【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 14        スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 16  コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#
#                                                   url          ID  \
# 0   https://page.auctions.yahoo.co.jp/jp/auction/r...  r403051715
# 1   https://page.auctions.yahoo.co.jp/jp/auction/4...   494400497
# 2   https://page.auctions.yahoo.co.jp/jp/auction/p...  p776025227
# 3   https://page.auctions.yahoo.co.jp/jp/auction/w...  w409986028
# 4   https://page.auctions.yahoo.co.jp/jp/auction/v...  v737950789
# 5   https://page.auctions.yahoo.co.jp/jp/auction/v...  v722095628
# 6   https://page.auctions.yahoo.co.jp/jp/auction/b...  b492567732
# 7   https://page.auctions.yahoo.co.jp/jp/auction/w...  w408157122
# 8   https://page.auctions.yahoo.co.jp/jp/auction/k...  k483497145
# 9   https://page.auctions.yahoo.co.jp/jp/auction/f...  f446222729
# 10  https://page.auctions.yahoo.co.jp/jp/auction/o...  o396314149
# 11  https://page.auctions.yahoo.co.jp/jp/auction/u...  u375426818
# 12  https://page.auctions.yahoo.co.jp/jp/auction/p...  p763925243
# 13  https://page.auctions.yahoo.co.jp/jp/auction/b...  b468858355
# 14  https://page.auctions.yahoo.co.jp/jp/auction/o...  o395835275
# 15  https://page.auctions.yahoo.co.jp/jp/auction/q...  q384628921
# 16  https://page.auctions.yahoo.co.jp/jp/auction/u...  u366330133
#
#                                                 Title   main key  Category
# 0   0    コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品...  star wars   75708.0
# 1   1    コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリア...  star wars   75708.0
# 2   2    ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# Name...  star wars   75708.0
# 3   3    【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# Name...  star wars   75708.0
# 4   4    コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# N...  star wars   75708.0
# 5   5    訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フ...  star wars   75708.0
# 6   6    未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシ...  star wars   75708.0
# 7   7    スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コ...  star wars   75708.0
# 8   8    コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Excl...  star wars   75708.0
# 9   9    内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギ...  star wars   75708.0
# 10  10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1...  star wars   75708.0
# 11  11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ...  star wars   75708.0
# 12  12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & ...  star wars   75708.0
# 13  13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ...  star wars   75708.0
# 14  14    スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 ...  star wars   75708.0
# 15  15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1...  star wars   75708.0
# 16  16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10ス...  star wars   75708.0

# %% [markdown]
# #### main key, Categoryの列を、他列の行数まで同じ値で埋め合わせるためfillna(pad)を使えると思ったが、Numpyでは無理みたい。

# %% [markdown]
# #### SKUを全ループ追加分を作成し、その列を横付け

# %%
id_col = list_df['ID'] #.iloc[] # SKU
id_col
# Out:
# 0     r403051715
# 1      494400497
# 2     p776025227
# 3     w409986028
# 4     v737950789
# 5     v722095628
# 6     b492567732
# 7     w408157122
# 8     k483497145
# 9     f446222729
# 10    o396314149
# 11    u375426818
# 12    p763925243
# 13    b468858355
# 14    o395835275
# 15    q384628921
# 16    u366330133
# Name: ID, dtype: object

# %%
sku_list = []
# def left(text, n):
# 	return text[:n]
def right(text, n): # https://qiita.com/ty21ky/items/111d8d636fe7f6e29621
    return text[-n:]
for id in id_col:  # ランダムID + ID + 日付
    sku_list.append(right(str(uuid4()) + '-' + str(id) + datetime.now().strftime('-%Y%m-%d%H-%M%S'), 50))
# SKUの列＝C
# sht2.range('C{}'.format(str(nextRow_sku))).options(transpose=True).value = sku_list
sr_sku = pd.Series(sku_list, name='SKU')
sr_sku
# merge, オーtフィルする列、sku_list, 全てDFにまとめ、一発で・to_sql
# concatすることで、mergeの行数の分、df3の行数も増やしたい
# これで一番最後にsr_titleをconcatしたいのだが、なんせ翻訳が制限で途中で中止される。
# 他の列と行数が変わってしまう。その翻訳できなかった差分は、とりあえず何かしら値を入れたら良い。> fillna()
# titleは fillna(0)で、df3 は前の行の値（mainkey）だから fillna(method='pad') ＞これ同時にできる？
# concat = pd.concat([merge, sr_title, sr_sku]).fillna(0) # title列、未翻訳＝空白の行を0で埋める。https://deepage.net/features/pandas-manipulate-na.html#%E5%9F%BA%E6%9C%AC%E7%9A%84%E3%81%AA%E4%BD%BF%E3%81%84%E6%96%B9-1
# 下にして
# Out:
# 0     46ab-858e-7c9d35848b24-r403051715-202008-2114-...
# 1     -4e4a-93e3-a9987458b635-494400497-202008-2114-...
# 2     4af4-9bf8-36dd4555f716-p776025227-202008-2114-...
# 3     4e39-955b-5fd6e5870c3f-w409986028-202008-2114-...
# 4     4996-88af-f6bc628ba489-v737950789-202008-2114-...
# 5     4c44-9f5b-121ce37a1d50-v722095628-202008-2114-...
# 6     46ac-bd42-d8cf82b1e489-b492567732-202008-2114-...
# 7     4932-99fe-de5fed88e785-w408157122-202008-2114-...
# 8     49b7-a6a2-614bd5b83cb6-k483497145-202008-2114-...
# 9     4f2a-a427-db9b7d0468c0-f446222729-202008-2114-...
# 10    467f-9484-0d4dabad4e9a-o396314149-202008-2114-...
# 11    4538-aa92-492019f9b1b8-u375426818-202008-2114-...
# 12    4f09-a3f1-4df0b3a024fa-p763925243-202008-2114-...
# 13    473e-807b-0e76dbeff2e0-b468858355-202008-2114-...
# 14    4dc9-9591-4efc0e419f1a-o395835275-202008-2114-...
# 15    430b-9577-0e2df7b65e31-q384628921-202008-2114-...
# 16    4672-97cc-f8a6ce65cf46-u366330133-202008-2114-...
# Name: SKU, dtype: object

# %%
global concat
concat2 = pd.concat([list_df, sr_sku], axis=1) 

# ここでSKU列に「SKU」と列名を与える。なぜ0~4はNaN？
concat2
# 一行のエクセル関数DFを追加、下までフィル
# global concat2
# concat2 = pd.concat([concat, main_categ_df]).fillna(method='pad') #'ffill' と同等 # 空白を前の行で埋める https://riptutorial.com/ja/pandas/example/6188/%E4%B8%8D%E8%B6%B3%E3%81%97%E3%81%A6%E3%81%84%E3%82%8B%E5%80%A4%E3%82%92%E5%9F%8B%E3%82%81%E8%BE%BC%E3%82%80
# Out:
#                                                  タイトル  \
# 0          コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品)
# 1   コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリアン、ボバ・...
# 2                ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# 3                【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# 4             コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# 5   訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア ...
# 6   未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシディアス ...
# 7   スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コトブキヤ ...
# 8   コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Exclusive...
# 9   内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギュア ko...
# 10  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール...
# 11  ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ「リミテッド...
# 12  即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & チューバッカ...
# 13  【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ版 1/7ス...
# 14        スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 超レア
# 15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品)
# 16  コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PV...
#
#                                                   url          ID  \
# 0   https://page.auctions.yahoo.co.jp/jp/auction/r...  r403051715
# 1   https://page.auctions.yahoo.co.jp/jp/auction/4...   494400497
# 2   https://page.auctions.yahoo.co.jp/jp/auction/p...  p776025227
# 3   https://page.auctions.yahoo.co.jp/jp/auction/w...  w409986028
# 4   https://page.auctions.yahoo.co.jp/jp/auction/v...  v737950789
# 5   https://page.auctions.yahoo.co.jp/jp/auction/v...  v722095628
# 6   https://page.auctions.yahoo.co.jp/jp/auction/b...  b492567732
# 7   https://page.auctions.yahoo.co.jp/jp/auction/w...  w408157122
# 8   https://page.auctions.yahoo.co.jp/jp/auction/k...  k483497145
# 9   https://page.auctions.yahoo.co.jp/jp/auction/f...  f446222729
# 10  https://page.auctions.yahoo.co.jp/jp/auction/o...  o396314149
# 11  https://page.auctions.yahoo.co.jp/jp/auction/u...  u375426818
# 12  https://page.auctions.yahoo.co.jp/jp/auction/p...  p763925243
# 13  https://page.auctions.yahoo.co.jp/jp/auction/b...  b468858355
# 14  https://page.auctions.yahoo.co.jp/jp/auction/o...  o395835275
# 15  https://page.auctions.yahoo.co.jp/jp/auction/q...  q384628921
# 16  https://page.auctions.yahoo.co.jp/jp/auction/u...  u366330133
#
#                                                 Title   main key  Category  \
# 0   0    コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品...  star wars   75708.0
# 1   1    コトブキヤ ARTFX+ ：スターウォーズ　６キャラクター (ルーク、マンダロリア...  star wars   75708.0
# 2   2    ダースモール ARTFX コトブキヤ STAR WARS スターウォーズ
# Name...  star wars   75708.0
# 3   3    【新品未開封】希少　スターウォーズ　コトブキヤ ARTFX カイロ・レン
# Name...  star wars   75708.0
# 4   4    コトブキヤ ARTFX+ ダースベイダー クラウド・シティ版 スター・ウォーズ
# N...  star wars   75708.0
# 5   5    訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フ...  star wars   75708.0
# 6   6    未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン ダースシ...  star wars   75708.0
# 7   7    スターウォーズ artfx タイファイター・パイロット フィギュア スタチュー コ...  star wars   75708.0
# 8   8    コトブキヤ ARTFX+ スターウォーズ R2-Q5 2013 NYCC Excl...  star wars   75708.0
# 9   9    内未開封 スターウォーズ artfx コトブキヤ ヨーダvsパルパティーン フィギ...  star wars   75708.0
# 10  10    コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1...  star wars   75708.0
# 11  11    ダースベイダー2種セット●壽屋コトブキヤ「ARTFX+クラウド・シティ版」●セガ...  star wars   75708.0
# 12  12    即決　コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ & ...  star wars   75708.0
# 13  13    【未開封】コトブキヤ ARTFX スター・ウォーズ ダース・モール ライトアップ...  star wars   75708.0
# 14  14    スターウォーズ コトブキヤ オビワンケノービ エピソードⅡ フィギュア 未開封 ...  star wars   75708.0
# 15  15    コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1...  star wars   75708.0
# 16  16    コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10ス...  star wars   75708.0
#
#                                                   SKU
# 0   46ab-858e-7c9d35848b24-r403051715-202008-2114-...
# 1   -4e4a-93e3-a9987458b635-494400497-202008-2114-...
# 2   4af4-9bf8-36dd4555f716-p776025227-202008-2114-...
# 3   4e39-955b-5fd6e5870c3f-w409986028-202008-2114-...
# 4   4996-88af-f6bc628ba489-v737950789-202008-2114-...
# 5   4c44-9f5b-121ce37a1d50-v722095628-202008-2114-...
# 6   46ac-bd42-d8cf82b1e489-b492567732-202008-2114-...
# 7   4932-99fe-de5fed88e785-w408157122-202008-2114-...
# 8   49b7-a6a2-614bd5b83cb6-k483497145-202008-2114-...
# 9   4f2a-a427-db9b7d0468c0-f446222729-202008-2114-...
# 10  467f-9484-0d4dabad4e9a-o396314149-202008-2114-...
# 11  4538-aa92-492019f9b1b8-u375426818-202008-2114-...
# 12  4f09-a3f1-4df0b3a024fa-p763925243-202008-2114-...
# 13  473e-807b-0e76dbeff2e0-b468858355-202008-2114-...
# 14  4dc9-9591-4efc0e419f1a-o395835275-202008-2114-...
# 15  430b-9577-0e2df7b65e31-q384628921-202008-2114-...
# 16  4672-97cc-f8a6ce65cf46-u366330133-202008-2114-...

# %%
# ここでID出力。マクロ. Elems の場合は全てのIDを出力せず、追加されたIDを都度都度ファイルへ加えていく
# このPyで追加したアイテムのIDだけでいい
# macro = app.macro('PERSONAL.XLSB!OutputActiveID_Txt_elem') # 状態列が空白の行から全てのIDをテキストへ
# macro()
# shutil.move('C:/Users/Kazuki Yuno/Desktop/00.Myself/04.Buyer/1.利益計算/db_check_yahoo_elem.txt',
#             'C:/Windows/System32/ScrapingTool_Init/sample_codes/db_check_yahoo_elem.txt')
elems_id_txt = r'C:/Windows/System32/ScrapingTool_Init/sample_codes/zaico-fixcan/db_check_yahoo_elem.txt'
id_col.to_csv(elems_id_txt,
          header=None, index=None, sep=' ')#, mode='a') # mBall_elem_zaicoは、追加された分のIDの価格だけでいい

# time.sleep(10) # 時間置かないと、elems_yahooでTxtファイルがないと言われることがある
# wb2.save()
# app.kill()
#

# %% [markdown]
# ### 価格・説明文・状態の要素取得、エクセル表計算を参考にした計算をSQLで

# %% [markdown]
# #### 新しいVer

# %%
def remove_space_htmlTag(s):
    p = re.compile(r"<[^>]*?>") # htmlTagを削除
    remove = p.sub("", s)
    space = re.sub(r'\s+', ' ', remove).strip()  # 連続する空白を1つのスペースに置き換え、前後の空白を削除した新しい文字列を取得する。
    return space.replace('[', '').replace(']', '') # [] を置換


def remove_space_htmlTag_pr(s): # 価格用
    p = re.compile(r"<[^>]*?>")
    remove = p.sub("", s)
    remove = re.sub(r'\s+', ' ', remove).strip()#.sub(r'(円（税込\d+円）', remove)
    p = re.compile(r'(円（税込 \d+,\d+ 円）)')  # 連続する空白を1つのスペースに置き換え、前後の空白を削除した新しい文字列を取得する。
    remove = p.sub("", remove)
    # space = re.sub(r'(円（税込\d+円）)', space)
    return remove.replace('[', '').replace(']', '').replace('円（税 0 円） ', '')


 # mergeのURL列から、新たにitemID 列を導き出す
def extract_key(url): # URLからキー（URLの末尾のISBN）を抜き出す。
    m = re.search(r'/([^/]+)$', url) # /([^/]+)$
    return m.group(1)

# %%
import csv # は要らない

# from sample_codes import elems_yahoo4 as elyahoo
el_csv = r'C:/Users/kazuki_juno/Desktop/00.Myself/04.Buyer/1.利益計算/db_yahoo_elements.csv'
with open(el_csv, 'w', encoding='utf-8-sig', newline='', errors='ignore') as f:
    # elyahoo.main(f, el_csv, concat2)
    #     el_main(f, el_csv, elems_id_txt)
# Out:
#   File "<ipython-input-76-2c7e1564b429>", line 7
#     #     el_main(f, el_csv, elems_id_txt)
#                                           ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# #### 税込 \d+ だと、数値int64でないといけないかも、11,620のように 間に,があるとマッチしないか

# %%
import csv # は要らない
el_csv = r'C:/Users/kazuki_juno/Desktop/00.Myself/04.Buyer/1.利益計算/db_yahoo_elements.csv'
with open(el_csv, 'w', encoding='utf-8-sig', newline='', errors='ignore') as f:
    
    # def el_main(f, el, txt):
    writer = csv.writer(f)
    with open(elems_id_txt) as f: #
        page_id_list = [str(row) for row in f]
    # img_list = []
    # id_list = []
    # arr = np.empty([0, 2])
    arr_descon = np.empty([0, 3]) # ここは３列か
    arr_img = np.empty([0, 2]) # 0, 2 だと２列分のみ＞ 
    arr_pr = np.empty([0, 2])
    # print(arr)
    for page_id in page_id_list:#[347:352]:#[:10]:
        print(page_id)
        url = f'https://page.auctions.yahoo.co.jp/jp/auction/{page_id}'
        try:
            res = requests.get(url.strip())
            res.raise_for_status()
            soup = bs4.BeautifulSoup(res.text, "html.parser")

            # 説明文/description
            #scrape(soup, writer, url, arr) #, img_list, id_list, arr)
            elems = soup.select(
                '#adoc > div.ProductExplanation__body.highlightWordSearch > div.ProductExplanation__commentArea > div')
            elems_d = remove_space_htmlTag(str(elems))
            print(elems_d)

            #状態/condition
            elems1 = soup.select(
                '#adoc > div.ProductExplanation__body.highlightWordSearch > div.ProductExplanation__tableArea > table > tbody > tr:nth-child(2) > td > ul > li')  # [0].extract()
            # print(elems1)
            elems_c = remove_space_htmlTag(str(elems1))
            print(elems_c)

            # 画像
            elem_img = soup.select("div[class='ProductImage__inner'] img")
            for tmp in elem_img:
                # global src_fact
                src_fact = tmp.attrs["src"]  # attrsを用いてhtmlのsrc=の中身をsrc_factに格納していきました。
#                 print(src_fact)
                # if src_fact == []:
                #     print("画像が見つかりません。。。")
                # else:
                page_id_for_scrape = url.split('/')[-1]
                list = [elems_d, elems_c, page_id_for_scrape]
                writer.writerow(list)
                time.sleep(0.5)
                
                img_np = np.array([[page_id_for_scrape], [src_fact]]).T  # transpose()  # elem_img]) # src_list]
                arr_img = np.r_[arr_img, img_np]

                
            # 価格
            price = soup.select('dl > dd.Price__value')#[0]
            price2 = remove_space_htmlTag_pr(str(price))
            # print(price2)
            # pr_list.append(elems_d)
            日件 = soup.select('.Count__number')
            日件2 = remove_space_htmlTag_pr(str(日件))
            # print(日件2)
            if '終了' in 日件2:  # 終了品は elems=価格 を空白に
                # print(日件2)
                price2 = ', '  # 空白のみだと、「, 」で分割する時エラー起きるから
                print(price2)  # + ' 終了')

            else:  # 出品中なら
                pr_title = soup.select('dt[class="Price__title"]')
                pr_title2 = remove_space_htmlTag_pr(str(pr_title))
                # print(pr_title2)
                if '現在価格' not in pr_title2:  # 現在価格が無い＝即決価格のみなら
                    price2 = ', ' + price2  # 価格の手前
                    print(price2)  # + ' 即決のみ')
                else:  # 現在価格あるなら
                    print(price2)  # + ' 現在') # ここは最初のprice2になる

        except requests.exceptions.HTTPError as err:
            print(err)
            elems_d = ''# httpエラーのIDが飛ばされていたので
            elems_c = ''
            src_fact = ''
            price2 = ''

        # try とexcept のスコープ両方に入れいてたが、zaicoは双方の後に、以下を入れてる
        page_id_for_scrape = url.split('/')[-1]

        list = [elems_d, elems_c, page_id_for_scrape]
        writer.writerow(list)

        dc_np = np.array([[page_id_for_scrape], [elems_d], [elems_c]]).T  # transpose()  # elem_img]) # src_list]
        arr_descon = np.r_[arr_descon, dc_np]
        
#         img_np = np.array([[page_id_for_scrape], [src_fact]]).T  # transpose()  # elem_img]) # src_list]
#         arr_img = np.r_[arr_img, img_np]
        
        pr_np = np.array([[page_id_for_scrape], [price2]]).T  # transpose()  # elem_img]) # src_list]
        arr_pr = np.r_[arr_pr, pr_np]
        
        time.sleep(1)
    
#         break
        
    img_df = pd.DataFrame(arr_img)
    print(img_df)
    img_df.to_csv('df_img.csv')
# Out:
# r403051715
#
#  商品名 コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品) 商品コード B000BVYQRG 商品説明 (中古品)コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット【メーカー名】壽屋 コトブキヤ【メーカー型番】1012244【ブランド名】壽屋(KOTOBUKIYA)【商品説明】コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット当店では初期不良に限り、商品到着から7日間は返品を受付けております。 商品名に(新品未使用品)の記載がある商品に関しましては、 当店で買取した商品ですので中古となりますが開封のみの未使用品となります。 ※画像はイメージです。 流用していますので、実際の商品とは 元箱、付属品などとは違いがある場合がございます。 ※「特典」「限定」「初回」「○○付」などの表記があっても、付属の特典がない場合があります。 プロダクトコード等も付属していなかったり、使用済みで使えない可能性があります。 ご不明な点は事前にご質問ください。 万が一、品切れの場合はご連絡致します。 ご注文からお届けまで 1、ご注文⇒ご注文は24時間受け付けております。 2、注文確認⇒ご注文時、オーダーフォーム等必要事項を入力お願い致します。 3、在庫確認⇒新品国内在庫：3～5営業日でお届け。 新品海外在庫：2週間程度でお届け。 ※中古品は受注後に、再メンテナンス、梱包しますので お届けまで3～7営業日とお考え下さい。 4、入金確認⇒前払い決済をご選択の場合、ご入金確認後、配送手配を致します。 5、出荷⇒配送準備が整い次第、出荷致します。配送業者、追跡番号等の詳細をご連絡致します。 6、到着⇒出荷後、1～3日後に商品が到着します。 ※離島、北海道、九州、沖縄は遅れる場合がございます。ご了承下さい。 ★支払方法 ・ジャパンネット銀行 ・各種クレジットカード ・代引発送 ★発送詳細 ・本州一律880円 (北海道2,500円、沖縄、離島は3,300円) ※配送業者、発送方法は選択できません。 代引の場合、手数料として660円頂きます。 電話対応はしておりませんので質問等は質問、メールにてお願い致します。 古物商 埼玉県公安委員会 第431250036960号
#  やや傷や汚れあり
# ,  5,560
# 494400497
#
#  2020年5月以降に購入したもので、全て未使用に近い状況です。 ルーク、マンダロリアン、C-3PO＆R2-D2はBOX付きで、全てのアクセサリがついています。ダースベイダーはBOX はありませんが、全てのアクセサリがついています。＋ ブランド：コトブキヤのARTFX+ シリーズ ＋ スケール：1/10 ＋ ボバフェットとダースベイダーのボックスはありません。 ＋ ベビーヨーダ (ザ・チャイルド)はブラックシリーズです。 キャラクター - ルークスカイウォーカー（X-Wing Pilot、ARTFX+）- C-3PO＆R2-D2（ARTFX+） - マンダロリアン（ARTFX+）- ベビーヨーダ / ザ・チャイルド (ブラックシリーズ）- ボバフェット（クラウドシティ、ARTFX+） - ダースベイダー（クラウドシティ、ARTFX+） Keywords - Star Wars - Luke Skywalker - R2-D2 and C-3PO - Mandalorian - Baby Yoda / The Child - Darth Vader - Boba Fett
#  未使用に近い
#  30,0009%下げて出品中 値下げ前の価格 33,000 円 , 36,000
# p776025227
#
#  ダースモール ARTFX コトブキヤ【新品未開封】&amp; 送料サービス§§ ご覧頂き、ありがとうございます §§「発光ギミック」搭載！「刺青」を再現！スター・ウォーズEP1において、圧倒的な存在感を誇ったシスの暗黒卿 「ダース・モール」今回は上半身の衣を脱ぎ、ダブルブレードのライトセーバーを構えた迫力の構図で登場。ライトセーバーはLEDによる発光ギミック付！シスの忠誠の証「刺青」をまとったボディーを再現！日本画を彷彿とさせる「ジャポニズムあふれるスタイル」で立体化。日本発信のスター・ウォーズを表現しました。■仕様：PVC塗装済み簡易組立キット 【スケール】1/7 【サイズ】約300mm■ブランド：KOTOBUKIYA(コトブキヤ)■シリーズ：ARTFX■原作：スター・ウォーズ■キャラ：ダース・モール▲注意事項※箱の状態は写真にてご確認ください。保管は段ボールの中に入れて保管しており、箱の状態は良いかと思いますが神経質な方はご入札お控えください※完全未開封の為、フィギュアの写真追加は出来ませんので、ご理解ください※入札から48時間経過してもご連絡頂けない場合は落札者様都合にてキャンセルさせて頂きます※新品未開封品です。1度開封してしまうと新品ではなくなるので、NCNRでお願いします※評価の悪い方、評価1を満たさない方は入札を取り消す場合がございます。評価1を満たさない方は入札後、必ずメッセージお願い致します＊記載内容にご納得頂けます方のご入札、お待ちしております
#  未使用
# ,  13,500
# w409986028
#
#  新品未使用品です。暗所で保管していました。現在は、オークションでも、見かけない、超貴重品かと、思われます。十字型のライトセーバーはライトアップギミック付でスター・キラー基地での戦闘シーンをイメージしたダイナミックなバトルポーズで立体化です。ひるがえした衣装の質感や裾に付着した雪など細やかな造型になっています。ベースにはダース・ベイダーのマスクをイメージしたジオラマに仕上がっております。
#  未使用
# ,  45,000
# v737950789
#
#  コトブキヤの ARTFX+ ダースベイダー クラウド・シティ版 です。購入後ガラスケースにて飾り、その後冷暗所に保管しておりましたが、コレクション整理の為に出品致します。欠品は、ございませんが、中古品のためご理解頂ける方のみ入札お願いします。ノークレームノーリターンでお願い致します。
#  目立った傷や汚れなし
#  4,00011%下げて出品中 値下げ前の価格 4,500 円 , 4,500
# v722095628
#
#  コンディション詳細こちらの商品は「状態ランク：D」ですS未使用品または新品同様A汚れやダメージが目立たない美品B使用感はあるが、ダメージが比較的目立たない良品C使用感があり汚れやダメージが見られるが、問題なく日常で使用できるD汚れや破れ、シミなど目立つかなり使用感の見られる訳あり品Jジャンク品、または素材、部品取りのものサイズ詳細W39.5cmD22cmH44cm *採寸サイズの為、多少の誤差はご容赦ください。アイテム詳細アイテム名訳あり スターウォーズ ダース・ベイダー ジェダイの帰還版 ARTFX 1/7 フィギュア コトブキヤ管理番号bti0017426商品説明採寸は外箱のサイズです。特記事項※動作未確認のため、こちらの商品は『訳あり』とさせて頂きます。ご理解頂ける方のみ購入をご検討ください。 ※簡易清掃を行いましたが、取り切れない汚れや埃等がございます。付属品―※中古品のため、リボンや替えのベルトなど、新品購入時の付属品が揃っていない場合がございます。 商品画像に写っているもの、商品説明文に記載のあるものが全てとなります。ラインARTFX＋型番1/7カラーマルチカラー系その他素材―※素材については商品画像に記載している場合がございますご注文の前に確認ください。 ・ご使用のモニター設定により色味が異なる場合があります・デザイン上、意図的に加工を施した商品があります・類似品、贋物等は一切取り扱っておりません・【中古】表記商品については商品状態を確認のうえ、中古品の性質をご理解頂きご購入下さい。・「訳あり」「動作未確認」と記載のある商品は、動作の保証ができかねます。 動作しない場合でも返品は承れません。ご了承下さい。
#  全体的に状態が悪い
#  4,800 , 6,450
# b492567732
#
#  【お支払いについて】落札から48時間以内にお支払いをお願い致しますそれまでにご連絡、ご入金なければ落札者様都合で削除させて頂く事があります。 その場合、落札者様には自動で悪い評価がつきますのでご理解下さい。出品商品に関して質問等あれば落札前にお願い致します【商品説明】未開封箱にダメージあり箱の接着が剥がれている部分あり【箱ありの商品に関して】中古品、未使用品に関わらず、箱の状態を極度に気にする方は入札をお控え下さい素人保管なので未使用であっても箱に傷、汚れ、ホコリ、凹みなどがある場合がございます【発送に関して】梱包には定形外紙、プチプチ、段ボール、包装紙などを使用します ↑↑↑これらは全て当方が実費で負担しています。送料に誤差が生じる場合がございますが、返金は出来ません。送料＋梱包代とお考え下さい。土日祝は基本的に発送はしておりません。評価はまだ浅いですが最後まで誠意を持って対応しますのでお願い致します。
#  未使用
# ,  50,000
# w408157122
#
#  【お支払いについて】落札から48時間以内にお支払いをお願い致しますそれまでにご連絡、ご入金なければ落札者様都合で削除させて頂く事があります。 その場合、落札者様には自動で悪い評価がつきますのでご理解下さい。出品商品に関して質問等あれば落札前にお願い致します【商品説明】箱開封。内ブリスターは未開封か開封か分からないので中古品でお願い致します箱の状態はあまり良くないです【箱ありの商品に関して】中古品、未使用品に関わらず、箱の状態を極度に気にする方は入札をお控え下さい素人保管なので未使用であっても箱に傷、汚れ、ホコリ、凹みなどがある場合がございます【発送に関して】同梱可能です梱包には定形外紙、プチプチ、段ボール、包装紙などを使用します ↑↑↑これらは全て当方が実費で負担しています。送料に誤差が生じる場合がございますが、返金は出来ません。送料＋梱包代とお考え下さい。土日祝は基本的に発送はしておりません。評価はまだ浅いですが最後まで誠意を持って対応しますのでお願い致します。
#  やや傷や汚れあり
# ,  25,000
# k483497145
#
#  □商品詳細 開封済みですが、中身に目立ったイタミはなく良好な状態です。本体の入ったブリスターはテープが切れており開封済みですが、メダルの入った部分はテープが止まったたの未開封の状態です。説明書の入った袋も同様に未開封です。箱はスレ・キズ・色あせがあります(プチプチで保護包装しております)。 □発送詳細 発送作業を代行業者に依頼している関係で、配送方法は指定できません。「おまかせ」になります（ヤマト宅急便になることが多いです)。追跡番号あり、補償ありです。日時指定可能です。( 8-12時、14-16時、16-18時、18-20時、19-21時)局留めは対応できません。原則、ダンボール箱での梱包ですが、薄いものは封筒、大きいものはプチプチ包装になることがあります。 □注意事項 商品説明と著しく異なる場合は返品・返金などさせていただきます。 写真に映っているものがすべてです。 ほかにも出品しています。よろしければご覧ください Yahoo!かんたん決済（クレカ・ネットバンク）がご利用いただけます + + + この商品説明はオークションプレートメーカー2で作成しました + + + No.202.001.007 この商品はヤフオク!一括出品ツール「オークタウン」で出品されています。
#  目立った傷や汚れなし
# ,  7,4806%下げて出品中 値下げ前の価格 7,980 円
# f446222729
#
#  【お支払いについて】落札から48時間以内にお支払いをお願い致しますそれまでにご連絡、ご入金なければ落札者様都合で削除させて頂く事があります。 その場合、落札者様には自動で悪い評価がつきますのでご理解下さい。出品商品に関して質問等あれば落札前にお願い致します【商品説明】箱のみ開封箱に破れなどあり【箱ありの商品に関して】中古品、未使用品に関わらず、箱の状態を極度に気にする方は入札をお控え下さい素人保管なので未使用であっても箱に傷、汚れ、ホコリ、凹みなどがある場合がございます【発送に関して】梱包には定形外紙、プチプチ、段ボール、包装紙などを使用します ↑↑↑これらは全て当方が実費で負担しています。送料に誤差が生じる場合がございますが、返金は出来ません。送料＋梱包代とお考え下さい。土日祝は基本的に発送はしておりません。評価はまだ浅いですが最後まで誠意を持って対応しますのでお願い致します。
#  未使用に近い
# ,  50,000
# o396314149
#
#  コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケール 未開封です。外箱サイズH約25×W約25×D約45cm底の止めシールが一枚切れています。外箱は所々にダメージがありますが、中身は未使用です。未使用品ですが、あくまでも中古としてご理解の上ご購入ください。また購入後のクレーム、返品返金は一切お断り致します。予めご了承ください。
#  未使用
#  8,555, 8,666
# u375426818
#
#  ●壽屋コトブキヤ「スター・ウォーズ ARTFX+ ダースベイダー クラウド・シティ版」 左手指差しポーズパーツ、箱、説明書有り ※クラウド・シティのベースのみ有りません。 足裏のマグネットで、メタルプレート製ベースに固定出来ます。 全高 約21cm（1/10スケール）台座込みで。 ●セガ「スター・ウォーズ リミテッドプレミアムフィギュア＃ダースベイダー」 全高 約30.5cm 台座込みでライトサーベル先端まで 以上、2つをセットで。 2つとも綺麗な方ですが、あくまでも中古品ですので、神経質な方はご遠慮下さい。 「ゆうパック100サイズ」での発送です。 箱が約90cmありますので、全体をエアキャップで包みその上から包装紙で包む簡易梱包になります。 箱はある程度の傷みが有りますし、あくまでもフィギュアの保護用緩衝材程度にお考え下さい。 ↓ 【静岡県内 1280円】 【関東・信越・北陸・東海・近畿 1330円】 【東北・中国・四国 1440円】 【九州 1560円】 【沖縄 1900円】 【北海道 1890円】 申し訳ありませんが、ルーズな方、モラルの無い方がいるため、細かく説明を記載しています。★ 「商品説明」と、出品者情報の「自己紹介(フォロー)」欄を必ず読んで下さい。入札された場合は、全てに同意したものとします。★取引ナビをなかなか開始しない方がおり、こちらも送料の連絡が出来ず、迷惑しております。携帯電話は、ガラケーで、自宅にあるパソコンでしか確認出来ませんので即答は出来ません。以下の文章は、出品している全種共通文言です。 【入札のお断りについて】 以下の入札者はご遠慮下さい。守れない方は「落札者都合」でキャンセルとし、自動的にヤフオクから「非常に悪い」の評価が付きます。ブラックリストにも登録します。×新規の方、悪い評価が4つ以上ある方、悪い割合が高い方、1ヶ月以内に悪い評価がある方は、NG ※出品での悪い評価は関係なし。※どうしても欲しい場合は、事前に質問欄からご相談下さい。 ×落札日に取引ナビを開示出来ない方は、NG ※夜勤等で遅くなる場合は事前に連絡を下さい。 ×送料連絡後、48時間以内に入金出来ない方は、NG ×「受取連絡」を配達完了から24時間以内に出来ない方は、NG ×代行業者は、依頼主が入金して来なかったら音信不通になるし、取引ナビの開示と入金も遅いため、NG (領収書の発行、ID等は記載しません。) ※取引履歴のコメントと、1ヶ月当りの取引件数の多さ、住所末尾に独自のIDが付いている等で、代行業者であることはすぐ分かります。×当方が発送した梱包状態のままで、海外等へ転送するのはNG 個人情報を他人に知らせるのはNG×日本語の理解力や、筆記力が無い方、翻訳機能を使っている方、日本の習慣やモラルが理解出来ない方、海外発送を希望する方は、NG×即決希望、値下げ交渉、複数落札したいから値引きを迫る方等は、NG×品物や、梱包状態を過剰に気にされる神経質な方は、NG×他の出品者と過去のやりとりで暴言、報復評価をした方は、NG 【梱包について】 ●同梱希望品がある場合は、そのことを落札者様から連絡して下さい。連絡がない場合は個別発送になります。●基本的に3日以内の品でしたら、同梱可能ですが、明らかに形状が違う等、同梱出来ない場合もあります。●持込割引は、持ち込んだ人に払われる対価と考えております。それを考慮した金額で出品しています。承知出来ない方はご遠慮下さい。●基本的に簡易梱包です。厳重梱包を希望される方は必ず前もって連絡して下さい。(送料が高くなる場合があります。) 【発送について】 ★到着連絡をしなかったり、虚偽の発言をする方が何人もいたため、追跡が可能な発送しか致しません。★なるべく早く発送していますが、基本的に入金確認後、土・日・祝日を除く3日以内の発送となります。せっかちの方、お急ぎの方はご遠慮下さい。 ※状況により、早めに発送する場合がございます。「同梱を希望したい商品を入札したから」と後から言われても困りますので、同梱希望品がある場合は事前にご連絡下さい。●記載してある方法以外での発送は致しません。【その他】 ●お取引の簡略化のため、挨拶文等は、お互い「無し」でお願いします。●到着連絡をして頂ければ、評価は無くて構いません。評価を頂いた場合のみ、こちらから評価させて頂きます。●評価不要の方はこちらにも評価しないで下さい。(評価されると反射的に評価を入れてしまうため。) 評価コメントは、定型文になります。●写真に写っている品が全てです。※台などは撮影用なので付帯致しません。●初期不良、欠品、経年による変色・劣化・破損が生じていても返品は受付けません。●再出品を繰り返している商品もありますので、撮影した時期より、経年劣化している場合がございます。気になる場合は入札前にご質問下さい。●商品状態の項目が、既存文からしか選べられなくなったため、中古やジャンクの表記が出来なくなっています。よって、あくまで個人的な感じ方に近い既存文を選んでいますが、落札者様とは感じ方が違う場合が有りますので商品説明欄をよくお読み下さい。老眼のため、見落としが有ったり、知識不足で分からなかったり間違えていたりする場合も有ります。●写真の色合いと実物の色合いに差があることがあります。特に赤の発色が悪く写ります。写真だと細かい箇所等が写りづらかったり、綺麗に見えがちです。●タバコは喫いませんし、ペットも飼っていませんが、臭いがある場合があります。●急な事情や、パソコントラブル等で連絡が出来ない場合が有ります。当方から5日以上連絡が無い場合は、「自己紹介(フォロー)」欄をまず確認して下さい。
#  目立った傷や汚れなし
#  5,400, 5,500
# p763925243
#
#  ★ コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ &amp; チューバッカ フィギュア 外箱開封のみの未使用品です。※パッケージの擦れ、傷等、細かく状態を気になさる方、神経質な方のご入札はご遠慮願います。※－評価の多い方、新規の方のご入札はご遠慮願います。こちらの判断により削除させていただきます。※自己紹介欄及び、商品画像をご覧頂き、ノークレーム ノーリターン ノーキャンセルでお願い致します。気になることがありましたらＱ＆Ａよりお気軽にご質問をお願い致します。★通常ゆうパック８０サイズにてお送り致します。※ゆうパック着払いも可能ですが、箱サイズにより送料が高くなる場合がございますがご了承願います。※代金引換、定形外郵便（普通郵便）、メール便等での発送は致しておりません。※オークション終了、当方連絡後、2日以内のご返事5日以内のご入金をお願い致します。 ◎◎◎申し訳御座いませんが、海外発送を希望の方は入札なさらないようお願い致します。落札後でも判り次第、落札者の都合で削除させて頂きます。(Sellerwillnotship internationally.）◎◎◎
#  未使用
# ,  14,999
# b468858355
#
#  □商品詳細 未開封・未使用です。箱に小スレ・小キズがあります。 □発送詳細 発送作業を代行業者に依頼している関係で、配送方法は指定できません。「おまかせ」になります（ヤマト宅急便になることが多いです)。追跡番号あり、補償ありです。日時指定可能です。( 8-12時、14-16時、16-18時、18-20時、19-21時)局留めは対応できません。原則、ダンボール箱での梱包ですが、薄いものは封筒、大きいものはプチプチ包装になることがあります。 □注意事項 商品説明と著しく異なる場合は返品・返金などさせていただきます。 写真に映っているものがすべてです。 ほかにも出品しています。よろしければご覧ください Yahoo!かんたん決済（クレカ・ネットバンク）がご利用いただけます + + + この商品説明はオークションプレートメーカー2で作成しました + + + No.202.001.007 この商品はヤフオク!一括出品ツール「オークタウン」で出品されています。
#  未使用
# ,  22,9804%下げて出品中 値下げ前の価格 23,980 円
# o395835275
#
#  コトブキヤより発売されたスターウォーズの 1/7スケールのソフトビニールフィギュアから『オビ-ワン ケノービ』を出品します。未開封・未使用ですが、古い商品の為、箱に劣化が見られます。大きさは、未開封のため、正確にはわかりませんが、箱の縦の高さが約40cmです。今では手に入らない劇レア商品となります。
#  未使用
#  8,000, 10,000
# q384628921
#
#  商品名 コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/1(中古品) 商品コード B0042ES4B2 商品説明 (中古品)コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/10スケール PVC塗装済み簡易組立キット【メーカー名】壽屋(KOTOBUKIYA)【メーカー型番】18472【ブランド名】壽屋(KOTOBUKIYA)【商品説明】コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/10スケール PVC塗装済み簡易組立キット当店では初期不良に限り、商品到着から7日間は返品を受付けております。 商品名に(新品未使用品)の記載がある商品に関しましては、 当店で買取した商品ですので中古となりますが開封のみの未使用品となります。 ※画像はイメージです。 流用していますので、実際の商品とは 元箱、付属品などとは違いがある場合がございます。 ※「特典」「限定」「初回」「○○付」などの表記があっても、付属の特典がない場合があります。 プロダクトコード等も付属していなかったり、使用済みで使えない可能性があります。 ご不明な点は事前にご質問ください。 万が一、品切れの場合はご連絡致します。 ご注文からお届けまで 1、ご注文⇒ご注文は24時間受け付けております。 2、注文確認⇒ご注文時、オーダーフォーム等必要事項を入力お願い致します。 3、在庫確認⇒新品国内在庫：3～5営業日でお届け。 新品海外在庫：2週間程度でお届け。 ※中古品は受注後に、再メンテナンス、梱包しますので お届けまで3～7営業日とお考え下さい。 4、入金確認⇒前払い決済をご選択の場合、ご入金確認後、配送手配を致します。 5、出荷⇒配送準備が整い次第、出荷致します。配送業者、追跡番号等の詳細をご連絡致します。 6、到着⇒出荷後、1～3日後に商品が到着します。 ※離島、北海道、九州、沖縄は遅れる場合がございます。ご了承下さい。 ★支払方法 ・ジャパンネット銀行 ・各種クレジットカード ・代引発送 ★発送詳細 ・本州一律880円 (北海道2,500円、沖縄、離島は3,300円) ※配送業者、発送方法は選択できません。 代引の場合、手数料として660円頂きます。 電話対応はしておりませんので質問等は質問、メールにてお願い致します。 古物商 埼玉県公安委員会 第431250036960号
#  やや傷や汚れあり
# ,  10,231
# u366330133
#
#  商品名 コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PVC製 塗装済(中古品) 商品コード B0108P5IEY 商品説明 (中古品)コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PVC製 塗装済み簡易組立フィギュア【メーカー名】壽屋(KOTOBUKIYA)【メーカー型番】JUL152456【ブランド名】壽屋(KOTOBUKIYA)【商品説明】コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケール PVC製 塗装済み簡易組立フィギュア当店では初期不良に限り、商品到着から7日間は返品を受付けております。 商品名に(新品未使用品)の記載がある商品に関しましては、 当店で買取した商品ですので中古となりますが開封のみの未使用品となります。 ※画像はイメージです。 流用していますので、実際の商品とは 元箱、付属品などとは違いがある場合がございます。 ※「特典」「限定」「初回」「○○付」などの表記があっても、付属の特典がない場合があります。 プロダクトコード等も付属していなかったり、使用済みで使えない可能性があります。 ご不明な点は事前にご質問ください。 万が一、品切れの場合はご連絡致します。 ご注文からお届けまで 1、ご注文⇒ご注文は24時間受け付けております。 2、注文確認⇒ご注文時、オーダーフォーム等必要事項を入力お願い致します。 3、在庫確認⇒新品国内在庫：3～5営業日でお届け。 新品海外在庫：2週間程度でお届け。 ※中古品は受注後に、再メンテナンス、梱包しますので お届けまで3～7営業日とお考え下さい。 4、入金確認⇒前払い決済をご選択の場合、ご入金確認後、配送手配を致します。 5、出荷⇒配送準備が整い次第、出荷致します。配送業者、追跡番号等の詳細をご連絡致します。 6、到着⇒出荷後、1～3日後に商品が到着します。 ※離島、北海道、九州、沖縄は遅れる場合がございます。ご了承下さい。 ★支払方法 ・ジャパンネット銀行 ・各種クレジットカード ・代引発送 ★発送詳細 ・本州一律880円 (北海道2,500円、沖縄、離島は3,300円) ※配送業者、発送方法は選択できません。 代引の場合、手数料として660円頂きます。 電話対応はしておりませんので質問等は質問、メールにてお願い致します。 古物商 埼玉県公安委員会 第431250036960号
#  やや傷や汚れあり
# ,  13,873
#                0                                                  1
# 0   r403051715\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 1    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 2    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 3    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 4    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# ..           ...                                                ...
# 87  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 88  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 89  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 90  q384628921\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 91  u366330133\n  https://auctions.c.yimg.jp/images.auctions.yah...
#
# [92 rows x 2 columns]

# %%
    # DF化
    # 説明、状態の DF化
    descon_df = pd.DataFrame(arr_descon, columns=['ID', '説明', '状態']).iloc[:, 1:3]#.column  # 0. 1行目のみ
    #     descon_df.column = ['説明', '状態']
    descon_df
# Out:
#                                                    説明            状態
# 0    商品名 コトブキヤ ハン・ソロ スターウォーズ ARTFX 1/7 組み立てキット(中古品...     やや傷や汚れあり
# 1    2020年5月以降に購入したもので、全て未使用に近い状況です。 ルーク、マンダロリアン、C...       未使用に近い
# 2    ダースモール ARTFX コトブキヤ【新品未開封】&amp; 送料サービス§§ ご覧頂き、...          未使用
# 3    新品未使用品です。暗所で保管していました。現在は、オークションでも、見かけない、超貴重品か...          未使用
# 4    コトブキヤの ARTFX+ ダースベイダー クラウド・シティ版 です。購入後ガラスケースに...   目立った傷や汚れなし
# 5    コンディション詳細こちらの商品は「状態ランク：D」ですS未使用品または新品同様A汚れやダメ...    全体的に状態が悪い
# 6    【お支払いについて】落札から48時間以内にお支払いをお願い致しますそれまでにご連絡、ご入金...          未使用
# 7    【お支払いについて】落札から48時間以内にお支払いをお願い致しますそれまでにご連絡、ご入金...     やや傷や汚れあり
# 8    □商品詳細 開封済みですが、中身に目立ったイタミはなく良好な状態です。本体の入ったブリスタ...   目立った傷や汚れなし
# 9    【お支払いについて】落札から48時間以内にお支払いをお願い致しますそれまでにご連絡、ご入金...       未使用に近い
# 10   コトブキヤ ARTFX STAR WARS ダース・ベイダー 新たなる希望版 1/7スケー...          未使用
# 11   ●壽屋コトブキヤ「スター・ウォーズ ARTFX+ ダースベイダー クラウド・シティ版」 左...   目立った傷や汚れなし
# 12   ★ コトブキヤ ARTFX+ スターウォーズ フォースの覚醒版 ハンソロ &amp; チュ...          未使用
# 13   □商品詳細 未開封・未使用です。箱に小スレ・小キズがあります。 □発送詳細 発送作業を代行...          未使用
# 14   コトブキヤより発売されたスターウォーズの 1/7スケールのソフトビニールフィギュアから『オ...          未使用
# 15   商品名 コトブキヤ スター・ウォーズ ARTFX+ ストームトルーパー ビルドパック 1/...     やや傷や汚れあり
# 16   商品名 コトブキヤ ARTFX+ STAR WARS AT-AT ドライバー 1/10スケ...     やや傷や汚れあり

# %%
    # def img_spread(arr):  # (img_list):
    img_df = pd.DataFrame(arr_img, columns=['ID', '画像'])#.iloc[:, 1:]
    img_df
# Out:
#               ID                                                 画像
# 0   r403051715\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 1    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 2    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 3    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 4    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# ..           ...                                                ...
# 87  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 88  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 89  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 90  q384628921\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 91  u366330133\n  https://auctions.c.yimg.jp/images.auctions.yah...
#
# [92 rows x 2 columns]

# %%
    img_df.columns = ['ID', '画像'] # 列名指定 # ここに価格２列を追加
    img_df
#     img_df.to_csv('df_img.csv')
# Out:
#               ID                                                 画像
# 0   r403051715\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 1    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 2    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 3    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 4    494400497\n  https://auctions.c.yimg.jp/images.auctions.yah...
# ..           ...                                                ...
# 87  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 88  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 89  o395835275\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 90  q384628921\n  https://auctions.c.yimg.jp/images.auctions.yah...
# 91  u366330133\n  https://auctions.c.yimg.jp/images.auctions.yah...
#
# [92 rows x 2 columns]

# %%
    def f(a): # 単なるGroupBy, apply ではなく、関数 f を組むことで、画像URLを一列に集約するだけでなく、各列に分割までできた  # https://ja.stackoverflow.com/questions/24845/python%E3%81%AEpandas%E3%81%A7-%E7%B8%A6%E6%8C%81%E3%81%A1%E3%81%AE%E3%83%87%E3%83%BC%E3%82%BF%E3%82%92%E6%A8%AA%E6%8C%81%E3%81%A1%E3%81%AB%E3%81%99%E3%82%8B%E3%82%88%E3%81%84%E6%96%B9%E6%B3%95%E3%82%92%E6%95%99%E3%81%88%E3%81%A6%E3%81%8F%E3%81%A0%E3%81%95%E3%81%84
        a.index = [0 for i in range(len(a))]
        del a['ID'] # 列名指定
        out = a[0:1]
        for i in range(1, len(a)):
            out = out.join(a[i:i + 1], rsuffix='{0}'.format(i))
        return out

    global grped # ここでiloc かける
    grped = img_df.groupby(img_df['ID'], sort=False).apply(f)
    grped
# Out:
#                                                                画像  \
# ID
# r403051715\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w409986028\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v737950789\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v722095628\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# k483497145\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# f446222729\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o396314149\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# u366330133\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
#
#                                                               画像1  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w409986028\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v737950789\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v722095628\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# k483497145\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# f446222729\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o396314149\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像2  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w409986028\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v737950789\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v722095628\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# k483497145\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# f446222729\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o396314149\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像3  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0                                                NaN
# w409986028\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v737950789\n 0                                                NaN
# v722095628\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# k483497145\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# f446222729\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o396314149\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像4  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0                                                NaN
# w409986028\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v737950789\n 0                                                NaN
# v722095628\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# k483497145\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# f446222729\n 0                                                NaN
# o396314149\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0                                                NaN
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像5  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0                                                NaN
# w409986028\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# v737950789\n 0                                                NaN
# v722095628\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# k483497145\n 0                                                NaN
# f446222729\n 0                                                NaN
# o396314149\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0                                                NaN
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像6  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0                                                NaN
# w409986028\n 0                                                NaN
# v737950789\n 0                                                NaN
# v722095628\n 0                                                NaN
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0                                                NaN
# k483497145\n 0                                                NaN
# f446222729\n 0                                                NaN
# o396314149\n 0                                                NaN
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0                                                NaN
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像7  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0                                                NaN
# w409986028\n 0                                                NaN
# v737950789\n 0                                                NaN
# v722095628\n 0                                                NaN
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0                                                NaN
# k483497145\n 0                                                NaN
# f446222729\n 0                                                NaN
# o396314149\n 0                                                NaN
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0                                                NaN
# o395835275\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像8  \
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0  https://auctions.c.yimg.jp/images.auctions.yah...
# p776025227\n 0                                                NaN
# w409986028\n 0                                                NaN
# v737950789\n 0                                                NaN
# v722095628\n 0                                                NaN
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0                                                NaN
# k483497145\n 0                                                NaN
# f446222729\n 0                                                NaN
# o396314149\n 0                                                NaN
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# b468858355\n 0                                                NaN
# o395835275\n 0                                                NaN
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN
#
#                                                               画像9
# ID
# r403051715\n 0                                                NaN
# 494400497\n  0                                                NaN
# p776025227\n 0                                                NaN
# w409986028\n 0                                                NaN
# v737950789\n 0                                                NaN
# v722095628\n 0                                                NaN
# b492567732\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# w408157122\n 0                                                NaN
# k483497145\n 0                                                NaN
# f446222729\n 0                                                NaN
# o396314149\n 0                                                NaN
# u375426818\n 0  https://auctions.c.yimg.jp/images.auctions.yah...
# p763925243\n 0                                                NaN
# b468858355\n 0                                                NaN
# o395835275\n 0                                                NaN
# q384628921\n 0                                                NaN
# u366330133\n 0                                                NaN

# %%
    grped = grped.iloc[:, 1:8].reset_index(drop=True) #, inplace=True) # おまけに、列名まで生成されてる!　ここで順を崩さないように
    # return grped
    grped  # https://stackoverflow.com/questions/48044542/groupby-preserve-order-among-groups-in-which-way
    # grped2 = grped.iloc[::-1] # 上下反転　
    # grped2.to_csv('merge_imgs2.csv') # これは列がバラバラのまま

    # elements.csvのID順は、ATKのそれと同じか？売り切れ品の要素も空白として記録してる？
    # cols = ['ゆ', 'の', 'ID']
    # id_df = pd.read_csv(el, # ここatk のID 列でもいい
    #                     header=None, names=cols).iloc[:, 2] # .reset_index() # , index='ID') # , columns=['ID'])
    # # id_df = pd.read_excel(atk, 'Sheet1', usecols=['ID_y'], skiprows=2, encoding='cp932')
    # print(id_df)
    # concat = pd.concat([id_df, grped], axis=1) # p.263 これ数値のみ？ 共通の越インデックスはあるが
    # id_df をつくりmergeさせるのは、grped のIDの並びがバラバラになっているのを、元のATK記載のIDリストの並びに戻すため
    # バラバラではなく、逆順になっていた
    # 2行分のズレが生じてるのは、このmergeによるものなのでは？では、マージではなく, 逆に並べる動作をすれば
    # merge = pd.merge(id_df, grped, on='ID', how='outer') # 外部結合なら、どちらかに無い値はNaNと表示される
    # print(merge)
#     grped.to_csv('merge_imgs3.csv')
    # update_atk(el, grped)
    # mBall_elem_zaicoは、新たに追加されたID分の価格を取得できればいい

# img_spread()


# def update_atk(el, grouped):
#     app = xw.App(visible=False)  # 新規アプリ実行環境を作成する
#     wb1 = app.books.open(el)
#     app.books.open("C:/Users/Kazuki Yuno/AppData/Roaming/Microsoft/Excel/XLSTART/PERSONAL.XLSB")
#     # macro = app.macro('PERSONAL.XLSB!elementsfromBS4')
#     # macro()
#     wb1.save()
#
#     atk = r"C:/Users/Kazuki Yuno/Desktop/00.Myself/04.Buyer/1.利益計算/AtackList_Buyer43.xlsx"
#     wb2 = app.books.open(atk)
#     # af_elems.autofill(atacklist)
#     # def el2at(el, atk, grped):
#         # 説明文、状態、画像、価格2種類、その他利益計算の列全て
#     sht1 = wb1.sheets[0]  # (1)にしていたが
#     sht2 = wb2.sheets[0]
#
#     lastRow1 = sht1.range('C1').end(-4121).row # Aにしていたが、今回のHTTPエラー時は空白ができることで、最下行はID列＝Cで。
#     # nextRow1 = lastRow1 + 1
#     lastRow2 = sht2.range('AZ4').end(-4121).row  # ATK 状態列＝AZの最下行
#     nextRow2 = lastRow2 + 1
#     # 生成したCSVからタイトル、URL, 画像URLをATKへ、最下行の下の行から追加
#     # col_list = ['G','I']
#     # for col in col_list:
#     # 説明と状態
#     desc = sht1.range('A1:A{}'.format(str(lastRow1))).options(ndim=2).value
#     sht2.range('J{}'.format(str(nextRow2))).value = desc
#     condi = sht1.range('B1:B{}'.format(str(lastRow1))).options(ndim=2).value
#     sht2.range('AZ{}'.format(str(nextRow2))).value = condi
#     # col_list = ['R','S','T','U','V']
#     # i = 2 # merge の３列目から
#     # for col, i in zip(col_list, range(2, 7)): # これで、２のときはR, ３のときはS、となる # https://uxmilk.jp/13726
#     # for col, i in zip(range(13, 18), range(2, 7)):
#     # while i < 7:
#
#     # 画像、通常版
#     sht2.range('P{}'.format(nextRow2)).options(
#         pd.DataFrame, expand='table', index=False, header=None).value = grouped.iloc[:, 1:8] # mergeの１－７列目に画像URLがある。8, 9 まであるアイテムも。
    # これまでのアイテムの画像データを一新＞ 4行目から
    # my_values = merge.iloc[:, 1:8]
    # sht2.range('P4').options(
    #     pd.DataFrame, expand='table', index=False, header=None).value = my_values  # index=False

    # el2at(wb1, wb2, grouped)

    # 次のPricesチェック(zaico.py )のため, output ID
    # zaico.py もつなげる ここはzaicoと繋がる必要はない。価格取得だけで良い
    # import された時はfixCancel動かさない、などの設定
    # 全ての行のIDを出力
    #
    # macro = app.macro('PERSONAL.XLSB!OutputActiveID_Txt')
    # macro()
    # shutil.move('C:/Users/Kazuki Yuno/Desktop/00.Myself/04.Buyer/1.利益計算/db_check_yahoo3.txt',
    #             'C:/Windows/System32/ScrapingTool_Init/sample_codes/db_check_yahoo3.txt')
    # wb2.save() # 読み取り専用の状態だと、保存できずエラーで終わる
    # wb1.close()
    # wb2.close()
    # app.kill()

    # 仕入先をスクレイプするごとに価格チェックすることになるから、ここは繋げない。最後に一括で価格やればいい

    # from sample_codes import zaico_yahoo as zyahoo  # if name == main は、
    # pr_csv = 'C:/Users/Kazuki Yuno/Desktop/00.Myself/04.Buyer/1.利益計算/db_check_yahoo4.csv'
    # with open(pr_csv, 'w', encoding='utf-8-sig', newline='', errors='ignore') as f2:
    #     zyahoo.main(f2, pr_csv)
    #     # pr_main(f2, pr_csv)
# Out:
#                                                   画像1  \
# 0                                                 NaN
# 1   https://auctions.c.yimg.jp/images.auctions.yah...
# 2   https://auctions.c.yimg.jp/images.auctions.yah...
# 3   https://auctions.c.yimg.jp/images.auctions.yah...
# 4   https://auctions.c.yimg.jp/images.auctions.yah...
# 5   https://auctions.c.yimg.jp/images.auctions.yah...
# 6   https://auctions.c.yimg.jp/images.auctions.yah...
# 7   https://auctions.c.yimg.jp/images.auctions.yah...
# 8   https://auctions.c.yimg.jp/images.auctions.yah...
# 9   https://auctions.c.yimg.jp/images.auctions.yah...
# 10  https://auctions.c.yimg.jp/images.auctions.yah...
# 11  https://auctions.c.yimg.jp/images.auctions.yah...
# 12  https://auctions.c.yimg.jp/images.auctions.yah...
# 13  https://auctions.c.yimg.jp/images.auctions.yah...
# 14  https://auctions.c.yimg.jp/images.auctions.yah...
# 15                                                NaN
# 16                                                NaN
#
#                                                   画像2  \
# 0                                                 NaN
# 1   https://auctions.c.yimg.jp/images.auctions.yah...
# 2   https://auctions.c.yimg.jp/images.auctions.yah...
# 3   https://auctions.c.yimg.jp/images.auctions.yah...
# 4   https://auctions.c.yimg.jp/images.auctions.yah...
# 5   https://auctions.c.yimg.jp/images.auctions.yah...
# 6   https://auctions.c.yimg.jp/images.auctions.yah...
# 7   https://auctions.c.yimg.jp/images.auctions.yah...
# 8   https://auctions.c.yimg.jp/images.auctions.yah...
# 9   https://auctions.c.yimg.jp/images.auctions.yah...
# 10  https://auctions.c.yimg.jp/images.auctions.yah...
# 11  https://auctions.c.yimg.jp/images.auctions.yah...
# 12  https://auctions.c.yimg.jp/images.auctions.yah...
# 13  https://auctions.c.yimg.jp/images.auctions.yah...
# 14  https://auctions.c.yimg.jp/images.auctions.yah...
# 15                                                NaN
# 16                                                NaN
#
#                                                   画像3  \
# 0                                                 NaN
# 1   https://auctions.c.yimg.jp/images.auctions.yah...
# 2                                                 NaN
# 3   https://auctions.c.yimg.jp/images.auctions.yah...
# 4                                                 NaN
# 5   https://auctions.c.yimg.jp/images.auctions.yah...
# 6   https://auctions.c.yimg.jp/images.auctions.yah...
# 7   https://auctions.c.yimg.jp/images.auctions.yah...
# 8   https://auctions.c.yimg.jp/images.auctions.yah...
# 9   https://auctions.c.yimg.jp/images.auctions.yah...
# 10  https://auctions.c.yimg.jp/images.auctions.yah...
# 11  https://auctions.c.yimg.jp/images.auctions.yah...
# 12  https://auctions.c.yimg.jp/images.auctions.yah...
# 13  https://auctions.c.yimg.jp/images.auctions.yah...
# 14  https://auctions.c.yimg.jp/images.auctions.yah...
# 15                                                NaN
# 16                                                NaN
#
#                                                   画像4  \
# 0                                                 NaN
# 1   https://auctions.c.yimg.jp/images.auctions.yah...
# 2                                                 NaN
# 3   https://auctions.c.yimg.jp/images.auctions.yah...
# 4                                                 NaN
# 5   https://auctions.c.yimg.jp/images.auctions.yah...
# 6   https://auctions.c.yimg.jp/images.auctions.yah...
# 7   https://auctions.c.yimg.jp/images.auctions.yah...
# 8   https://auctions.c.yimg.jp/images.auctions.yah...
# 9                                                 NaN
# 10  https://auctions.c.yimg.jp/images.auctions.yah...
# 11  https://auctions.c.yimg.jp/images.auctions.yah...
# 12  https://auctions.c.yimg.jp/images.auctions.yah...
# 13                                                NaN
# 14  https://auctions.c.yimg.jp/images.auctions.yah...
# 15                                                NaN
# 16                                                NaN
#
#                                                   画像5  \
# 0                                                 NaN
# 1   https://auctions.c.yimg.jp/images.auctions.yah...
# 2                                                 NaN
# 3   https://auctions.c.yimg.jp/images.auctions.yah...
# 4                                                 NaN
# 5   https://auctions.c.yimg.jp/images.auctions.yah...
# 6   https://auctions.c.yimg.jp/images.auctions.yah...
# 7   https://auctions.c.yimg.jp/images.auctions.yah...
# 8                                                 NaN
# 9                                                 NaN
# 10  https://auctions.c.yimg.jp/images.auctions.yah...
# 11  https://auctions.c.yimg.jp/images.auctions.yah...
# 12  https://auctions.c.yimg.jp/images.auctions.yah...
# 13                                                NaN
# 14  https://auctions.c.yimg.jp/images.auctions.yah...
# 15                                                NaN
# 16                                                NaN
#
#                                                   画像6  \
# 0                                                 NaN
# 1   https://auctions.c.yimg.jp/images.auctions.yah...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   https://auctions.c.yimg.jp/images.auctions.yah...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  https://auctions.c.yimg.jp/images.auctions.yah...
# 12  https://auctions.c.yimg.jp/images.auctions.yah...
# 13                                                NaN
# 14  https://auctions.c.yimg.jp/images.auctions.yah...
# 15                                                NaN
# 16                                                NaN
#
#                                                   画像7
# 0                                                 NaN
# 1   https://auctions.c.yimg.jp/images.auctions.yah...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   https://auctions.c.yimg.jp/images.auctions.yah...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  https://auctions.c.yimg.jp/images.auctions.yah...
# 12  https://auctions.c.yimg.jp/images.auctions.yah...
# 13                                                NaN
# 14  https://auctions.c.yimg.jp/images.auctions.yah...
# 15                                                NaN
# 16                                                NaN

# %%
    #  価格のDF化
    pr_df = pd.DataFrame(arr_pr, columns=['ID','価格2種'])
    pr_df
# Out:
#               ID                                       価格2種
# 0   r403051715\n                                  ,  5,560
# 1    494400497\n   30,0009%下げて出品中 値下げ前の価格 33,000 円 , 36,000
# 2   p776025227\n                                  ,  13,500
# 3   w409986028\n                                  ,  45,000
# 4   v737950789\n     4,00011%下げて出品中 値下げ前の価格 4,500 円 , 4,500
# 5   v722095628\n                             4,800 , 6,450
# 6   b492567732\n                                  ,  50,000
# 7   w408157122\n                                  ,  25,000
# 8   k483497145\n          ,  7,4806%下げて出品中 値下げ前の価格 7,980 円
# 9   f446222729\n                                  ,  50,000
# 10  o396314149\n                               8,555, 8,666
# 11  u375426818\n                               5,400, 5,500
# 12  p763925243\n                                  ,  14,999
# 13  b468858355\n        ,  22,9804%下げて出品中 値下げ前の価格 23,980 円
# 14  o395835275\n                              8,000, 10,000
# 15  q384628921\n                                 ,  10,231
# 16  u366330133\n                                 ,  13,873

# %% [markdown]
# #### 下記は「税込」の箇所が置換できなかった時。７番目の価格が上では無いのが気がかり。29000円。。＞＞単に、売れただけ

# %%
    #  価格のDF化
    pr_df = pd.DataFrame(arr_pr, columns=['ID','価格2種'])
    pr_df

# %% [markdown]
# #### https://stackoverflow.com/questions/57463127/splitting-a-column-in-dataframe-using-str-split-function
# #### DFの列をSplitしながら生成された列の名を割り当てる方法がいくつか

# %%
    #     print(pr_df)
    pr_df[['現在価格', '即決価格']] = pr_df['価格2種'].str.split(', ', expand=True) #.rename({0: 'First_Name', 1: 'Second_Name'})], axis=1)
    pr_df

# %%
    pr_df2 = pr_df.iloc[:, [2, 3]]  # drop([1], axis=1)
    
#     pr_df2.column = ['ID', '現在価格', '即決価格'] 
#     ここコメントアウトする2つのうち一つエラー消える

    pr_df2  # 0, 2, 3 列目のみ表示

# %%
    pr_csv = 'C:/Users/kazuki_juno/Desktop/00.Myself/04.Buyer/1.利益計算/db_check_yahoo4.csv'
    pr_df2.to_csv(pr_csv, header=False, index=False)

# %%
    concat3 = pd.concat([concat2, descon_df, grped, pr_df2], axis=1) #ここが問題
                         # 説明と状態、画像、価格
    concat3

# %%
    # # sql から追加した分を読み取る？
    # # 価格を含めたDFを、後の現在価格の列を用いて計算するため、
    # sql_df = pd.read_sql()

    # 一行の数式を設定後、設定後の列をdf[]で表し、新たに数式を設定するのでOK か
    # 一度dfにしないといけなくなるから、df[]は要らない
    # 価格系、これはzaico_yahooへ移行
    現在価格 = concat3['現在価格']#.iloc[0]
    即決価格 = concat3['即決価格']#.iloc[0]
    # 相場価格 = IF(AX8=0, AV8*3, AX8*1.5) # AX 即決価格、AV= 現在価格 # 両者とも、Zaicoした後にわかること
    即決価格

# %%
現在価格

# %%
concat3['相場価格'] = int(concat3['現在価格']) / int(concat3['即決価格'])

# %%
# print(concat3['即決価格'].dtype)
print(即決価格.dtype)

# %% [markdown]
# #### 列ごとReplace, この際、strを入れることで正常に置換できた（なぜかは不明

# %%
# print(
即決価格 = 即決価格.str.replace(' ', '').str.replace(' ', '').str.replace(',', '') #({' ': '', ',': ''}) #.astype('int64'))
print(即決価格)

# %% [markdown]
# #### astype(float64)は駄目だったので、to_numeric()で解決

# %%
# print(即決価格.astype('int64'))
print(pd.to_numeric(即決価格)) #astype('int64'))

# %% [markdown]
# #### まとめ

# %%
即決価格 = pd.to_numeric(concat3['即決価格'].str.replace(' ', '').str.replace(',', ''))
print(即決価格)

# %%
現在価格 = pd.to_numeric(concat3['現在価格'].str.replace(' ', '').str.replace(',', ''))
print(現在価格)

# %%
concat3['相場価格'] = 現在価格 / 即決価格
相場価格 = concat3['相場価格']
print(相場価格)

# %%
# 即決価格.isnull()
テスト = 現在価格*3
print(テスト)

# %%
# import math
# x = float('nan')
concat3['相場価格'] = 現在価格* 3 if 即決価格.isnull() else 現在価格* 1.5
相場価格 = concat3['相場価格']
print(相場価格)

# %% [markdown]
# #### 置換 ' 49,000'から 空白をなくす, かつ整数intにする. 列ごとする方法は？

# %%
 
    自己設定価格 = 0
    最高販売価格 = 0 if not str(max(相場価格, 自己設定価格)).isnumeric() else max(相場価格, 自己設定価格)
    最高販売価格
    # もし最大値が数値でないなら 0, 数値なら最大値
    #.isnumeric() # IFERROR(MAX(AD8,Q8,AF8),0) # AD相場価格 Q AF自己認定価格

# %%
    最安仕入価格 = min(即決価格) # 以降は、他ECから取得するようになったら　,
                    # 落札相場価格,仕入れ値上限, 価格_r, 価格_a, 価格_m, 価格_o)
                        #AN, AW8,AX8,AY8,AR8,BC8,BF8)
    最安仕入価格

# %%
# これはURL列から抽出
希望利益率 = 25
# =ROUNDDOWN(AH8*0.861-(AH8*BS8/100)-BL8,1) # AH最高売値 BS希望利益率 BL送料

# %%
    仕入送料 = 1000 #
    # 重量、ounce, pound, kg は、elems_yahoo4で取得するから、恐らく後で移行する
    ounce = 0
    pound = 0
    kg = 0.7 # ある列の計算式
    # integrated = if(ounce>0, ounce*0.03, if(pound>0,pound*0.45, if(kg>0,kg)))
    integrated = ounce * 0.03 if ounce > 0 else pound * 0.45 if pound > 0 else kg # if kg > 0 # https://note.nkmk.me/python-if-conditional-expressions/
    # integrated = if(ounce>0, ounce*0.03, if(pound>0,pound*0.45, if(kg>0,kg)))
    # if ounce > 0:
    #     integrated = ounce * 0.03
    # elif pound > 0:
    #     integrated = pound * 0.45
    # else kg > 0:
    #     integrated = kg
    # integ_col = df['integrated'] # 下記、df[integrated] 省略したい
    送料設定 = "0~0.3kg" if integrated<0.3 else "0.3~0.5kg" if integrated<0.5 else "0.5~0.8kg" if integrated<0.8 else\
        "0.8~1.0kg" if integrated<1 else "1.0~1.5kg" if integrated<1.5 else "1.5~2.0kg" if integrated<2 else\
            "2.0~2.5kg" if integrated<2.5 else "2.5~3.0kg" if integrated<3 else "3.5kg" if integrated<3.5 else\
            "4.0kg" if integrated<4 else "4.5kg" if integrated<4.5 else "5.0kg" if integrated<5 else\
            "5.5kg" if integrated < 5.5 else "6.0kg" if integrated < 6 else "7.0kg" if integrated< 7 else\
            "8.0kg" if integrated < 8 else "9.0kg" if integrated< 9 else '10.0kg以上' # Z = integrated
    # 送料設定_col = df['送料設定']
    送料 = 935 if 送料設定 == "0~0.3kg" else 1235 if 送料設定 == "0.3~0.5kg" else 1685 if 送料設定 == "0.5~0.8kg" else\
        1985 if 送料設定 == "0.8~1.0kg" else 2525 if 送料設定 == "1.0~1.5kg" else 3065 if 送料設定 == "1.5~2.0kg" else 5000
    # 後で 1985 if 送料設定 == "2.0~2.5kg" else 2525 if 送料設定 == "2.5~3.0kg" else 3065 if 送料設定 == "1.5~2.0kg" else\

    最高売値 = 最高販売価格 + 送料 + 仕入送料  # AG8+BL8+BI8
    最高売値

# %%
 
    粗利 = 最高売値 - 最安仕入価格  # AH8-AI8
    出品料 = 0 # なし
    # 最高売値col = df['最高売値']
    落札料 = 最高売値* 0.1
    Paypal = round(最高売値* 0.039, 1)
    支出合計 = sum(送料 + 出品料 + 落札料 + Paypal + 仕入送料)

    仕入れ値上限 = round(最高売値 * 0.861 - (最高売値 * 希望利益率 / 100) - 送料, 1)

    営業利益 = 粗利 - 支出合計
    利益率 = round(最高売値 / 営業利益* 100, 1)
    販売額 = round((最安仕入価格 + 送料)/ (1- 希望利益率/100- 0.139), 1) #=ROUNDDOWN((AI4+BL4)/(1-BS4/100-0.139),1)
    希望営業利益 = 販売額 - 最安仕入価格 - 支出合計
    Positive = round((最安仕入価格 + 送料)/ (1- 0.4- 0.139),1) # 40%
    Middle = round((最安仕入価格 + 送料)/ (1- 0.25- 0.139),1) # 25%
    Negative = round((最安仕入価格 + 送料)/ (1- 0.08- 0.139),1) # 8

    # 横一列のDF　これをto_sql 直前に追加、最終行までフィル
    funcs_df = pd.DataFrame({'kg': kg, 'integrated': integrated, '相場価格': 相場価格,
                             '最高販売価格': 最高販売価格, '最高売値': 最高売値, '最安仕入価格': 最安仕入価格,
                             '粗利': 粗利, '希望利益率': 希望利益率, '仕入送料': 仕入送料, '送料設定': 送料設定,
                             '送料': 送料, '出品料': 出品料, '落札料': 落札料, 'Paypal': Paypal,
                             '支出合計': 支出合計, '仕入れ値上限': 仕入れ値上限, '営業利益': 営業利益,
                            '利益率': 利益率, '販売額': 販売額, '希望営業利益': 希望営業利益,
                            'Positive': Positive, 'Middle': Middle, 'Negative': Negative})

# %%
    concat_fin = pd.concat([concat3, funcs_df], axis=1).fillna(method='pad')
    concat_fin.to_sql('atklist2', con=engine, if_exists='append',  # or replace
                   index=False)

# el_main()
